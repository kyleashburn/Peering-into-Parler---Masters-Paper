# %%
import pandas as pd
import json

# %% [markdown]
# ### Looking at languages

# %%
with open("lang_json", "r") as f_in:
    languages = json.load(f_in)

# %%
for file in languages:
    print(file)

    print("Overall")
    print(dict(list(data[file]["overall"]["percents"].items())[0:5]))

    print("Posts")
    # getting a dict of the top three values in terms of percents
    print(dict(list(data[file]["posts"]["percents"].items())[0:5]))

    print("Comments")
    # getting a dict of the top three values in terms of percents
    print(dict(list(data[file]["comments"]["percents"].items())[0:5]))
    print()
    print()
# Out:
# min_act.ndjson
# Overall
# {'English': 0.9114044261214148, 'Portuguese': 0.014093958679187417, 'Arabic': 0.010615983699807817, 'German': 0.009490957176058409, 'Spanish': 0.007557557542710176}
# Posts
# {'English': 0.9123226845147735, 'Arabic': 0.021350571381337276, 'Portuguese': 0.018283413923745852, 'Spanish': 0.007209063351678542, 'German': 0.0050858049517657974}
# Comments
# {'English': 0.9111030305964124, 'Portuguese': 0.012718873984029287, 'German': 0.010936839050876003, 'Japanese': 0.008355846354016417, 'Spanish': 0.007671942110742391}
#
#
# mod_act.ndjson
# Overall
# {'English': 0.8985848174148316, 'Arabic': 0.024445492266705893, 'Persian': 0.012141496052728606, 'Portuguese': 0.012114220156784417, 'Japanese': 0.006626502428549507}
# Posts
# {'English': 0.8629545145590047, 'Arabic': 0.03182369530039937, 'Portuguese': 0.030523601401812993, 'Persian': 0.012234896577714071, 'Japanese': 0.00987326052737519}
# Comments
# ...

# %% [markdown]
# ### Looking at domains

# %%
with open("top50dmns.json", "r") as f_in:
    domains = json.load(f_in)

# %%
for file in domains:
    print(file)

    print("Overall")
    print(dict(list(domains[file]["overall"].items())[0:10]))

    print("Posts")
    # getting a dict of the top three values in terms of percents
    print(dict(list(domains[file]["posts"].items())[0:10]))

    print("Comments")
    # getting a dict of the top three values in terms of percents
    print(dict(list(domains[file]["comments"].items())[0:10]))
    print()
    print()
# Out:
# min_act.ndjson
# Overall
# {'image-cdn.parler.com': 1807021, 'youtu.be': 311988, 'youtube.com': 179758, 'twitter.com': 154402, 'facebook.com': 145537, 'parler.com': 119088, 'i.imgur.com': 86139, 'rumble.com': 62455, 'media1.giphy.com': 43938, 'media2.giphy.com': 43613}
# Posts
# {'image-cdn.parler.com': 1280757, 'youtu.be': 275875, 'youtube.com': 166066, 'twitter.com': 149516, 'facebook.com': 141144, 'parler.com': 113697, 'i.imgur.com': 66624, 'rumble.com': 59848, 'thegatewaypundit.com': 41537, 'instagram.com': 41314}
# Comments
# {'image-cdn.parler.com': 526264, 'youtu.be': 36113, 'media1.giphy.com': 31967, 'media0.giphy.com': 31672, 'media3.giphy.com': 31470, 'media2.giphy.com': 31419, 'i.imgur.com': 19515, 'youtube.com': 13692, 'media4.giphy.com': 13476, 'share.par.pw': 5585}
#
#
# mod_act.ndjson
# Overall
# ...

# %% [markdown]
# ### Looking at Terms & Hashtags

# %%
with open("top50terms#s.json", "r") as f_in:
    terms = json.load(f_in)

# %%
terms
# Out:
# {'min_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'parler': 2616199,
#     'everyone': 2425771,
#     'looking': 2287494,
#     'forward': 2236112,
#     'joined': 2211886,
#     'looking forward': 2194244,
#     'meeting': 2193320,
#     'joined parler': 2181246,
#     'forward meeting': 2175400,
#     'parler looking': 2175205,
#     'looking forward meeting': 2175073,
#     'parler looking forward': 2174773,
#     'meeting everyone': 2174491,
#     'forward meeting everyone': 2174427,
#     'joined parler looking': 2174344,
#     'trump': 1592144,
#     'people': 1526405,
#     'like': 1213371,
#     'get': 1188364,
#     'know': 1119164,
#     'would': 1114237,
#     'u': 1074311,
#     'need': 1035396,
#     'one': 1002628,
#     'president': 901492,
#     'time': 846073,
#     'go': 756742,
#     'going': 725249,
#     'election': 717252,
#     'right': 714286,
#     'biden': 697858,
#     'think': 693403,
#     'want': 677818,
#     'see': 670639,
# ...

# %%
for file in terms:
    print(file)

    print("Terms")
    print("Overall")
    print(dict(list(terms[file]["overall"]["overall_terms"].items())[0:10]))
    
    print("Posts")
    # getting a dict of the top three values in terms of percents
    print(dict(list(terms[file]["posts"]["posts_terms"].items())[0:10]))

    print("Comments")
    # getting a dict of the top three values in terms of percents
    print(dict(list(terms[file]["comments"]["comments_terms"].items())[0:10]))
    print()
    
    print("Hashtags")
    print("Overall")
    print(dict(list(terms[file]["overall"]["overall_hashtags"].items())[0:10]))
    
    print("Posts")
    # getting a dict of the top three values in terms of percents
    print(dict(list(terms[file]["posts"]["posts_hashtags"].items())[0:10]))

    print("Comments")
    # getting a dict of the top three values in terms of percents
    print(dict(list(terms[file]["comments"]["comments_hashtag"].items())[0:10]))
    print()
    
    
    print()
    print()
# Out:
# min_act_lang_filtered_pre_proc.ndjson
# Terms
# Overall
# {'parler': 2616199, 'everyone': 2425771, 'looking': 2287494, 'forward': 2236112, 'joined': 2211886, 'looking forward': 2194244, 'meeting': 2193320, 'joined parler': 2181246, 'forward meeting': 2175400, 'parler looking': 2175205}
# Posts
# {'parler': 2277517, 'everyone': 2244500, 'looking': 2202431, 'forward': 2191525, 'joined': 2186611, 'meeting': 2180521, 'looking forward': 2180515, 'joined parler': 2177131, 'forward meeting': 2174760, 'parler looking': 2174715}
# Comments
# {'people': 1234047, 'trump': 1218146, 'like': 1025979, 'get': 980477, 'know': 957284, 'would': 952828, 'need': 867867, 'u': 832713, 'one': 814340, 'president': 682761}
#
# Hashtags
# Overall
# ...
