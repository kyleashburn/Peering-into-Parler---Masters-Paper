# %%
import ujson as json
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_json("ext_act_lang_filtered_pre_proc.ndjson", lines=True)

# %%
test = df.head(500)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Goals:
# 1. Pull the top n term freqs for overall, posts, and comments
# 2. Pull the top hashtags for each of those

# %% [markdown]
# Steps:
# 1. vectorize
# 2. pull feature names & counts for overall, posts and comments
#     * this requies filtering the dfs
#     * likely to be additional functions
# 3. check
#     * for those that are hashtags -> get those counts
#         * dict comp

# %%
# function to override the pre-proc that occurs within the vectorizer
# just returns the original string -> because I already had it clean
def dummy_func(x):   
    return x

# %%
def cust_tokenizer(x):
    return x.split()

# %%
# lightweight function to grep for hashtags
def hashtag_search(x):
    matches = re.findall(r"(#[a-zA-Z]+)", x)

    # need to adjust for empty lists...
    
    return matches

# %%
# function to take a given df and an n 
# returns the term freqs for that df sorted
def vect_tf(df, n):

    # initializing the vectorizer
    # setting min doc freq to 1 to avoid having things be too lossy
    # setting a pre-proc and tokenizer -> because the built-in ones are too aggressive
    vectorizer = CountVectorizer(min_df=1, preprocessor=dummy_func, tokenizer=cust_tokenizer, ngram_range=(1,3))

    
    # applying the vectorizer
    tf = vectorizer.fit_transform(df["bo"])

    # pulling the terms
    tf_feature_names = vectorizer.get_feature_names()

    # pulling the term counts
    term_counts = np.asarray(tf.sum(axis=0))[0]

    # making a dictionary w/terms and term counts
    term_freqs = dict(zip(tf_feature_names, term_counts))
    
    # making a dict w/terms and term counts for hashtags within this
    hashtag_freqs = {key:value for (key, value) in term_freqs.items() if "#" in key}

    hashtag_freqs = {key: value for key, value in hashtag_freqs.items()}
    
    top_n_freqs = dict((sorted(term_freqs.items(), key=lambda item: item[1],reverse=True))[0:n])
    
    top_n_hashtag_freqs = dict((sorted(hashtag_freqs.items(), key=lambda item: item[1],reverse=True))[0:n])
    
    return [top_n_freqs, top_n_hashtag_freqs]

# %%
# function to take given df, term_dict, and n -> returns overview of terms
def vect_overview(df, term_dict, n):
    
    overall = vect_tf(df, n)
    term_dict.setdefault("overall", {})
    term_dict["overall"].setdefault("overall_terms", overall[0])
    term_dict["overall"].setdefault("overall_hashtags", overall[1])
    
    posts = vect_tf(df[df["t"]=="p"], n)
    term_dict.setdefault("posts", {})
    term_dict["posts"].setdefault("posts_terms", posts[0])
    term_dict["posts"].setdefault("posts_hashtags", posts[1])

    
    comments = vect_tf(df[df["t"]=="c"], n)    
    term_dict.setdefault("comments", {})
    term_dict["comments"].setdefault("comments_terms", comments[0])
    term_dict["comments"].setdefault("comments_hashtag", comments[1])
    
    return term_dict

# %%
# current state -> trying to use the modification of a list as the return type
# ~ unsure if it's actually working
# expected is a triple nested dict {file:{overall:{posts_terms:{},posts_hashtags:{}}}}
#

# %%
file_list = ["min_act_lang_filtered_pre_proc.ndjson","mod_act_lang_filtered_pre_proc.ndjson",
             "ver_act_lang_filtered_pre_proc.ndjson","ext_act_lang_filtered_pre_proc.ndjson"]

# %%
# %%time

term_dict = {}

for file in file_list:
    
    # reading in the file
    df = pd.read_json(file, lines=True)
    
    # creating the dict entry for the file
    term_dict.setdefault(file, {})
    
    # attaching the vect overview dictionary to the term_dict for the file
    term_dict[file] = vect_overview(df, term_dict[file], 50)
# Out:
# CPU times: total: 2h 19min 48s
# Wall time: 2h 20min 2s

# %%
type(term_dict["min_act_lang_filtered_pre_proc.ndjson"]["overall"]["overall_terms"]["parler"])
# Out:
# numpy.int64

# %%
# converting the type from a numpy int to a regular int so we can serialize it into json
# kinda messy though
for file in term_dict:
    for level in term_dict[file]:
        for terms in term_dict[file][level]:
            for term in term_dict[file][level][terms]:
                term_dict[file][level][terms][term] = int(term_dict[file][level][terms][term]) 
                # pulls the value which is a number & converts to int

# %%
term_dict
# Out:
# {'min_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'parler': 2616199,
#     'everyone': 2425771,
#     'looking': 2287494,
#     'forward': 2236112,
#     'joined': 2211886,
#     'looking forward': 2194244,
#     'meeting': 2193320,
#     'joined parler': 2181246,
#     'forward meeting': 2175400,
#     'parler looking': 2175205,
#     'looking forward meeting': 2175073,
#     'parler looking forward': 2174773,
#     'meeting everyone': 2174491,
#     'forward meeting everyone': 2174427,
#     'joined parler looking': 2174344,
#     'trump': 1592144,
#     'people': 1526405,
#     'like': 1213371,
#     'get': 1188364,
#     'know': 1119164,
#     'would': 1114237,
#     'u': 1074311,
#     'need': 1035396,
#     'one': 1002628,
#     'president': 901492,
#     'time': 846073,
#     'go': 756742,
#     'going': 725249,
#     'election': 717252,
#     'right': 714286,
#     'biden': 697858,
#     'think': 693403,
#     'want': 677818,
#     'see': 670639,
#     'good': 645582,
#     'vote': 636927,
#     'god': 631022,
#     'country': 619694,
#     'state': 610820,
#     'cannot': 570234,
#     'make': 569662,
#     'say': 565698,
#     'democrat': 549137,
#     'back': 542847,
#     'take': 537435,
#     'let': 528123,
#     'year': 525520,
#     'never': 521115,
#     'new': 516877,
#     'way': 509555},
#    'overall_hashtags': {'#parlerconcierge': 349842,
#     '#newuser': 213819,
#     'question #parlerconcierge': 201837,
#     'know question #parlerconcierge': 201834,
#     '#truefreespeech': 147719,
#     '#newuser #truefreespeech': 147680,
#     'enjoy #newuser': 147677,
#     'interact enjoy #newuser': 147675,
#     '#truefreespeech #parlerconcierge': 147673,
#     '#newuser #truefreespeech #parlerconcierge': 147672,
#     'enjoy #newuser #truefreespeech': 147672,
#     '#trump2020': 100129,
#     'everyone #newuser': 63558,
#     'meeting everyone #newuser': 63550,
#     '#stopthesteal': 61109,
#     '#maga': 59659,
#     '#trump': 39045,
#     '#parler': 36795,
#     '#wwg1wga': 30020,
#     '#election2020': 20238,
#     '#qanon': 18324,
#     '#electionfraud': 18019,
#     '#maga2020': 17781,
#     '#kag': 17774,
#     '#voterfraud': 16580,
#     '#freedom': 15794,
#     '#covid19': 15756,
#     '#usa': 15627,
#     '#trumptrain': 15062,
#     '#parlerusa': 13686,
#     '#blm': 13016,
#     '#america': 12465,
#     '#patriots': 12423,
#     '#fakenews': 12307,
#     '#donaldtrump': 12137,
#     '#': 11830,
#     '#draintheswamp': 11179,
#     '#americafirst': 11053,
#     '#trump2020landslide': 10683,
#     '#joebiden': 10053,
#     '#biden': 9953,
#     '#obamagate': 9938,
#     '#thegreatawakening': 9901,
#     '#truth': 9815,
#     '#meme': 9519,
#     '#wethepeople': 9505,
#     '#antifa': 9443,
#     '#democrats': 9322,
#     '#fightback': 9318,
#     '#twexit': 8825}},
#   'posts': {'posts_terms': {'parler': 2277517,
#     'everyone': 2244500,
#     'looking': 2202431,
#     'forward': 2191525,
#     'joined': 2186611,
#     'meeting': 2180521,
#     'looking forward': 2180515,
#     'joined parler': 2177131,
#     'forward meeting': 2174760,
#     'parler looking': 2174715,
#     'looking forward meeting': 2174576,
#     'parler looking forward': 2174460,
#     'meeting everyone': 2174252,
#     'forward meeting everyone': 2174221,
#     'joined parler looking': 2174190,
#     'trump': 373998,
#     'people': 292358,
#     'u': 241598,
#     'president': 218731,
#     'get': 207887,
#     'election': 201554,
#     'one': 188288,
#     'like': 187392,
#     'time': 182826,
#     'biden': 178859,
#     'need': 167529,
#     'know': 161880,
#     'would': 161409,
#     'state': 146564,
#     'vote': 143572,
#     'god': 142448,
#     'day': 139534,
#     'going': 138270,
#     'right': 134939,
#     'see': 132813,
#     'want': 131989,
#     'new': 131881,
#     'go': 125779,
#     'country': 125703,
#     'say': 120668,
#     'year': 117979,
#     'let': 115888,
#     'make': 112308,
#     'news': 112277,
#     'good': 111922,
#     'america': 111110,
#     'american': 110429,
#     'think': 108599,
#     'democrat': 105152,
#     'take': 104098},
#    'posts_hashtags': {'#trump2020': 71998,
#     '#newuser': 65781,
#     'everyone #newuser': 63557,
#     'meeting everyone #newuser': 63549,
#     '#maga': 42728,
#     '#stopthesteal': 39058,
#     '#parler': 31462,
#     '#trump': 31269,
#     '#wwg1wga': 21755,
#     '#election2020': 17779,
#     '#electionfraud': 14878,
#     '#qanon': 14839,
#     '#covid19': 14029,
#     '#maga2020': 13560,
#     '#freedom': 13480,
#     '#voterfraud': 13447,
#     '#usa': 12813,
#     '#trumptrain': 12735,
#     '#parlerusa': 12522,
#     '#kag': 10820,
#     '#donaldtrump': 10680,
#     '#america': 10248,
#     '#blm': 9534,
#     '#patriots': 9285,
#     '#fakenews': 9036,
#     '#meme': 8848,
#     '#joebiden': 8746,
#     '#thegreatawakening': 8383,
#     '#americafirst': 8286,
#     '#biden': 7946,
#     '#draintheswamp': 7675,
#     '#truth': 7425,
#     '#conservative': 7285,
#     '#democrats': 7126,
#     '#trump2020landslide': 6875,
#     '#twexit': 6745,
#     '#covid': 6604,
#     '#presidenttrump': 6590,
#     '#obamagate': 6257,
#     '#republican': 6112,
#     '#election': 6034,
#     '#antifa': 5917,
#     '#2a': 5908,
#     '#keepamericagreat': 5873,
#     '#coronavirus': 5742,
#     '#wethepeople': 5706,
#     '#parler #parlerusa': 5663,
#     '#kag2020': 5581,
#     '#twitter': 5572,
#     '#fightback': 5496}},
#   'comments': {'comments_terms': {'people': 1234047,
#     'trump': 1218146,
#     'like': 1025979,
#     'get': 980477,
#     'know': 957284,
#     'would': 952828,
#     'need': 867867,
#     'u': 832713,
#     'one': 814340,
#     'president': 682761,
#     'time': 663247,
#     'go': 630963,
#     'going': 586979,
#     'think': 584804,
#     'right': 579347,
#     'want': 545829,
#     'see': 537826,
#     'good': 533660,
#     'biden': 518999,
#     'election': 515698,
#     'country': 493991,
#     'vote': 493355,
#     'god': 488574,
#     'welcome': 475758,
#     'cannot': 470253,
#     'state': 464256,
#     'make': 457354,
#     'say': 445030,
#     'democrat': 443985,
#     'back': 441513,
#     'never': 435031,
#     'take': 433337,
#     'hope': 427487,
#     'way': 419480,
#     'let': 412235,
#     'year': 407541,
#     'american': 392188,
#     'love': 388259,
#     'new': 384996,
#     'well': 380409,
#     'thank': 372231,
#     'thing': 368074,
#     'even': 361638,
#     'america': 349668,
#     '#parlerconcierge': 349653,
#     'look': 342740,
#     'parler': 338682,
#     'enjoy': 334643,
#     'keep': 326157,
#     'yes': 321206},
#    'comments_hashtag': {'#parlerconcierge': 349653,
#     'question #parlerconcierge': 201835,
#     'know question #parlerconcierge': 201833,
#     '#newuser': 148038,
#     '#truefreespeech': 147702,
#     '#newuser #truefreespeech': 147677,
#     'enjoy #newuser': 147674,
#     'interact enjoy #newuser': 147674,
#     '#truefreespeech #parlerconcierge': 147672,
#     '#newuser #truefreespeech #parlerconcierge': 147671,
#     'enjoy #newuser #truefreespeech': 147671,
#     '#trump2020': 28131,
#     '#stopthesteal': 22051,
#     '#maga': 16931,
#     '#wwg1wga': 8265,
#     '#trump': 7776,
#     '#kag': 6954,
#     '#': 6392,
#     '#parler': 5333,
#     '#1': 5237,
#     '#maga2020': 4221,
#     '#fightback': 3822,
#     '#trump2020landslide': 3808,
#     '#wethepeople': 3799,
#     '#obamagate': 3681,
#     '#antifa': 3526,
#     '#draintheswamp': 3504,
#     '#qanon': 3485,
#     '#blm': 3482,
#     '#boycottgeorgiarunoffs': 3332,
#     '#fakenews': 3271,
#     '#electionfraud': 3141,
#     '#patriots': 3138,
#     '#voterfraud': 3133,
#     '#progressive': 3084,
#     '#resist': 2865,
#     '#usa': 2814,
#     '#americafirst': 2767,
#     '#boycottgeorgia': 2738,
#     '#election2020': 2459,
#     '#kag2020': 2451,
#     '#georgia': 2440,
#     '#truth': 2390,
#     '#holdtheline': 2354,
#     '#trumptrain': 2327,
#     '#freedom': 2314,
#     '#trump2020 #kag': 2305,
#     '#america': 2217,
#     '#saveourchildren': 2217,
#     '#democrats': 2196}}},
#  'mod_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'parler': 6060833,
#     'people': 3999635,
#     'right': 3654882,
#     'welcome': 2765502,
#     'like': 2251085,
#     'share': 1936860,
#     'good': 1917401,
#     'life': 1855014,
#     'new': 1851661,
#     'well': 1807868,
#     'work': 1791745,
#     'trump': 1788077,
#     'free': 1767157,
#     'video': 1749847,
#     'also': 1738254,
#     'thought': 1722122,
#     'fighting': 1669452,
#     'place': 1669205,
#     'opinion': 1666236,
#     'check': 1657610,
#     'liberty': 1653793,
#     'special': 1652078,
#     'constitutional': 1648218,
#     'looking': 1647086,
#     'online': 1641220,
#     'people like': 1639259,
#     'space': 1639099,
#     'spent': 1637640,
#     'adult': 1636023,
#     'shadow': 1634478,
#     'banning': 1631720,
#     'openly': 1631504,
#     'constitutional right': 1631484,
#     'express': 1631140,
#     'excited': 1630782,
#     'youtube': 1630092,
#     'ideal': 1628213,
#     'shadow banning': 1626390,
#     'like parler': 1626064,
#     'accepts': 1625543,
#     'godgiven': 1625472,
#     'adult life': 1625034,
#     'page': 1624906,
#     'right express': 1624878,
#     'thought opinion': 1624872,
#     'special people': 1624850,
#     'throttling': 1624845,
#     'life fighting': 1624819,
#     'fighting liberty': 1624782,
#     'express thought': 1624747},
#    'overall_hashtags': {'#trump2020': 125902,
#     '#maga': 98509,
#     '#stopthesteal': 64053,
#     '#trump': 63432,
#     '#parler': 59063,
#     '#wwg1wga': 57675,
#     '#qanon': 38218,
#     '#kag': 37933,
#     '#maga2020': 35228,
#     '#usa': 33460,
#     '#patriots': 29922,
#     '#covid19': 28390,
#     '#trumptrain': 27174,
#     '#electionfraud': 27095,
#     '#americafirst': 26828,
#     '#voterfraud': 26786,
#     '#election2020': 26541,
#     '#parlerusa': 25371,
#     '#thegreatawakening': 25244,
#     '#obamagate': 25210,
#     '#donaldtrump': 24715,
#     '#freedom': 24705,
#     '#blm': 24618,
#     '#fakenews': 23507,
#     '#wethepeople': 22632,
#     '#democrats': 22486,
#     '#joebiden': 22413,
#     '#draintheswamp': 22240,
#     '#america': 22191,
#     '#news': 22123,
#     '#meme': 21036,
#     '#kag2020': 20157,
#     '#truth': 19908,
#     '#antifa': 19430,
#     '#biden': 18412,
#     '#wakeupamerica': 18146,
#     '#fightback': 17727,
#     '#backtheblue': 17437,
#     '#2a': 17393,
#     '#maga #kag': 16839,
#     '#deepstate': 16600,
#     '#presidenttrump': 16356,
#     '#twexit': 16157,
#     '#godwins': 15352,
#     '#trump2020landslide': 15333,
#     '#q': 15099,
#     '#covid': 14749,
#     '#savethechildren': 14723,
#     '#coronavirus': 14398,
#     '#keepamericagreat': 14280}},
#   'posts': {'posts_terms': {'trump': 457012,
#     'people': 287732,
#     'u': 238776,
#     'biden': 226824,
#     'president': 220788,
#     'election': 208187,
#     'get': 197013,
#     'one': 195364,
#     'like': 178840,
#     'time': 178017,
#     'state': 170116,
#     'would': 162114,
#     'democrat': 161201,
#     'news': 159955,
#     'know': 156446,
#     'vote': 156121,
#     'right': 152089,
#     'say': 149574,
#     'need': 146420,
#     'god': 136711,
#     'want': 133901,
#     'america': 133889,
#     'american': 133619,
#     'going': 128993,
#     'new': 128477,
#     'day': 127421,
#     'go': 123373,
#     'see': 116557,
#     'country': 112816,
#     'year': 110496,
#     'make': 109863,
#     'think': 107190,
#     'good': 106691,
#     'take': 104903,
#     '#trump2020': 102279,
#     'life': 100564,
#     'let': 100075,
#     'back': 99949,
#     'joe': 98051,
#     'medium': 93061,
#     'video': 91822,
#     'cannot': 90233,
#     'president trump': 88314,
#     'never': 87139,
#     'fraud': 84605,
#     'way': 83834,
#     'today': 82636,
#     'thing': 81639,
#     '#maga': 80916,
#     'watch': 80242},
#    'posts_hashtags': {'#trump2020': 102279,
#     '#maga': 80916,
#     '#trump': 55624,
#     '#stopthesteal': 52084,
#     '#parler': 50193,
#     '#wwg1wga': 45901,
#     '#qanon': 34383,
#     '#kag': 32299,
#     '#covid19': 26061,
#     '#election2020': 24717,
#     '#parlerusa': 24329,
#     '#electionfraud': 24057,
#     '#voterfraud': 23836,
#     '#maga2020': 23620,
#     '#americafirst': 22998,
#     '#usa': 22813,
#     '#thegreatawakening': 22535,
#     '#trumptrain': 22458,
#     '#patriots': 22147,
#     '#freedom': 21384,
#     '#news': 21065,
#     '#fakenews': 20914,
#     '#joebiden': 20740,
#     '#democrats': 20275,
#     '#meme': 19891,
#     '#donaldtrump': 19591,
#     '#blm': 19222,
#     '#draintheswamp': 18696,
#     '#truth': 18048,
#     '#america': 17962,
#     '#obamagate': 17644,
#     '#biden': 16958,
#     '#kag2020': 16809,
#     '#antifa': 16513,
#     '#maga #kag': 14782,
#     '#wakeupamerica': 14705,
#     '#deepstate': 14326,
#     '#fightback': 13688,
#     '#covid': 13639,
#     '#coronavirus': 13633,
#     '#keepamericagreat': 13501,
#     '#republican': 13326,
#     '#politics': 13035,
#     '#q': 13016,
#     '#election': 12989,
#     '#trump2020landslide': 12874,
#     '#presidenttrump': 12677,
#     '#qarmy': 12664,
#     '#conservative': 12245,
#     '#godwins': 12199}},
#   'comments': {'comments_terms': {'parler': 5993788,
#     'people': 3711903,
#     'right': 3502793,
#     'welcome': 2753664,
#     'like': 2072245,
#     'share': 1900095,
#     'good': 1810710,
#     'life': 1754450,
#     'well': 1744800,
#     'work': 1734941,
#     'new': 1723184,
#     'free': 1693074,
#     'thought': 1686985,
#     'also': 1683840,
#     'video': 1658025,
#     'fighting': 1653550,
#     'opinion': 1651846,
#     'constitutional': 1638844,
#     'liberty': 1638787,
#     'special': 1638019,
#     'place': 1637303,
#     'people like': 1635554,
#     'space': 1633013,
#     'adult': 1631948,
#     'spent': 1631942,
#     'online': 1631212,
#     'shadow': 1630665,
#     'constitutional right': 1629060,
#     'banning': 1628934,
#     'openly': 1628275,
#     'express': 1628070,
#     'excited': 1627750,
#     'ideal': 1626910,
#     'shadow banning': 1626146,
#     'like parler': 1625554,
#     'godgiven': 1625104,
#     'accepts': 1625068,
#     'adult life': 1624929,
#     'right express': 1624826,
#     'special people': 1624800,
#     'thought opinion': 1624788,
#     'throttling': 1624754,
#     'life fighting': 1624748,
#     'fighting liberty': 1624725,
#     'express thought': 1624721,
#     'new space': 1624692,
#     'excited new': 1624690,
#     'share work': 1624689,
#     'banning free': 1624688,
#     'work special': 1624682},
#    'comments_hashtag': {'#trump2020': 23623,
#     '#maga': 17593,
#     '#stopthesteal': 11969,
#     '#wwg1wga': 11774,
#     '#maga2020': 11608,
#     '#usa': 10647,
#     '#wethepeople': 10531,
#     '#parler': 8870,
#     '#trump': 7808,
#     '#patriots': 7775,
#     '#obamagate': 7566,
#     '#treason': 7155,
#     '#backtheblue': 6288,
#     '#usa usa': 6248,
#     '#usa usa usa': 6065,
#     '#2a': 5679,
#     '#kag': 5634,
#     '#blm': 5396,
#     '#ccp': 5354,
#     '#twexit': 5298,
#     '#chicanosfortrump': 5135,
#     '#donaldtrump': 5124,
#     '#trumptrain': 4716,
#     '#americans': 4474,
#     '#america': 4229,
#     '#1a': 4178,
#     '#fightback': 4039,
#     '#maga #maga2020': 3900,
#     'usa #chicanosfortrump': 3866,
#     'usa usa #chicanosfortrump': 3866,
#     '#qanon': 3835,
#     '#americafirst': 3830,
#     '#presidenttrump': 3679,
#     '#draintheswamp': 3544,
#     '#savethechildren': 3470,
#     '#wakeupamerica': 3441,
#     '#coupdetat': 3439,
#     '#novaccineforme': 3365,
#     '#kag2020': 3348,
#     '#walkaway': 3334,
#     '#freedom': 3321,
#     '#godwins': 3153,
#     '#dnc': 3102,
#     '#traitors': 3098,
#     '#electionfraud': 3038,
#     '#americans #patriots': 3005,
#     '#voterfraud': 2950,
#     '#': 2940,
#     '#dominion': 2925,
#     '#antifa': 2917}}},
#  'ver_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'u': 3209235,
#     'face': 3024780,
#     'alive': 2989390,
#     'go': 1658236,
#     'see': 1632660,
#     'free': 1609451,
#     'follow': 1596330,
#     'parler': 1593269,
#     'let': 1592652,
#     'well': 1581435,
#     'truth': 1561164,
#     'speech': 1551962,
#     'great': 1544039,
#     'let u': 1533814,
#     'actually': 1528219,
#     'free speech': 1524897,
#     'welcome': 1515480,
#     'looking': 1511969,
#     'forward': 1502951,
#     'glad': 1501880,
#     'keeping': 1497707,
#     'bias': 1496334,
#     'looking forward': 1492927,
#     'u go': 1492626,
#     'constant': 1492309,
#     'let u go': 1492123,
#     'glad see': 1491293,
#     'alive well': 1491197,
#     'see parler': 1490607,
#     'mixing': 1490555,
#     'parler free': 1490529,
#     'parler free speech': 1490498,
#     'glad see parler': 1490362,
#     'face let': 1490338,
#     'well looking': 1490331,
#     'keeping truth': 1490311,
#     'speech actually': 1490311,
#     'face let u': 1490310,
#     'actually alive': 1490307,
#     'face constant': 1490304,
#     'free speech actually': 1490303,
#     'truth alive': 1490302,
#     'alive face': 1490299,
#     'bias face': 1490298,
#     'constant bias': 1490298,
#     'well looking forward': 1490298,
#     'actually alive well': 1490297,
#     'alive face constant': 1490296,
#     'alive well looking': 1490296,
#     'bias face let': 1490296},
#    'overall_hashtags': {'#trump2020': 90277,
#     '#maga': 78037,
#     '#wwg1wga': 54211,
#     '#trump': 53975,
#     '#parler': 44965,
#     '#qanon': 42065,
#     '#kag': 41067,
#     '#stopthesteal': 39131,
#     '#usa': 30604,
#     '#meme': 29768,
#     '#maga #kag': 25733,
#     '#parlerconcierge': 25271,
#     'best rob #parlerconcierge': 25079,
#     'rob #parlerconcierge': 25079,
#     '#freedom': 24030,
#     '#america': 23084,
#     '#news': 22909,
#     '#memes': 22858,
#     '#fakenews': 22358,
#     '#americafirst': 22119,
#     '#covid19': 21779,
#     '#qarmy': 21643,
#     '#electionfraud': 20857,
#     '#keepamericagreat': 20387,
#     '#joebiden': 20345,
#     '#thegreatawakening': 20227,
#     '#voterfraud': 19267,
#     '#republican': 18446,
#     '#wethepeople': 18307,
#     '#bluelivesmatter': 18137,
#     '#maga2020': 17715,
#     '#parlerusa': 17658,
#     '#democrats': 17478,
#     '#trumptrain': 17440,
#     '#coronavirus': 17108,
#     '#donaldtrump': 17057,
#     '#obamagate': 16935,
#     '#draintheswamp': 16887,
#     '#2a': 16874,
#     '#teamtrump': 16751,
#     '#q': 16734,
#     '#trump2020landslide': 16068,
#     '#blm': 16029,
#     '#patriots': 15676,
#     '#antifa': 15291,
#     '#trump2020 #trump': 15052,
#     '#fightback': 14538,
#     '#qanon #qarmy': 13815,
#     '#saveourchildren': 13009,
#     '#alllivesmatter': 12993}},
#   'posts': {'posts_terms': {'trump': 518231,
#     'biden': 236391,
#     'news': 213938,
#     'president': 209183,
#     'people': 203052,
#     'democrat': 187359,
#     'u': 180274,
#     'election': 170712,
#     'say': 156515,
#     'state': 156511,
#     'one': 147890,
#     'time': 142954,
#     'right': 142831,
#     'get': 140920,
#     'new': 135531,
#     'vote': 133589,
#     'american': 131856,
#     'like': 129713,
#     'would': 123111,
#     'america': 119152,
#     'video': 110495,
#     'know': 109278,
#     'joe': 105337,
#     'want': 100969,
#     'day': 98828,
#     'fox': 97369,
#     'go': 95603,
#     'president trump': 95451,
#     'need': 93301,
#     'year': 89848,
#     'going': 87661,
#     'god': 86946,
#     'medium': 85966,
#     'police': 85221,
#     '#trump2020': 85138,
#     'back': 84109,
#     'life': 83639,
#     'fox news': 83424,
#     'make': 83366,
#     'see': 83323,
#     '2020': 83007,
#     'black': 81903,
#     'watch': 79639,
#     'country': 79210,
#     'take': 77514,
#     'china': 76244,
#     '#maga': 74651,
#     'good': 74494,
#     'white': 73121,
#     'free': 72787},
#    'posts_hashtags': {'#trump2020': 85138,
#     '#maga': 74651,
#     '#trump': 52333,
#     '#wwg1wga': 49891,
#     '#parler': 43233,
#     '#qanon': 41434,
#     '#kag': 39240,
#     '#stopthesteal': 37440,
#     '#meme': 29502,
#     '#usa': 29401,
#     '#maga #kag': 24359,
#     '#freedom': 23621,
#     '#news': 22843,
#     '#america': 22703,
#     '#memes': 22676,
#     '#americafirst': 21504,
#     '#fakenews': 21225,
#     '#covid19': 20986,
#     '#qarmy': 20981,
#     '#electionfraud': 20545,
#     '#keepamericagreat': 19826,
#     '#thegreatawakening': 19768,
#     '#joebiden': 19428,
#     '#voterfraud': 18562,
#     '#republican': 18141,
#     '#bluelivesmatter': 17939,
#     '#wethepeople': 17902,
#     '#parlerusa': 17535,
#     '#trumptrain': 17092,
#     '#donaldtrump': 16946,
#     '#maga2020': 16703,
#     '#obamagate': 16394,
#     '#teamtrump': 16376,
#     '#draintheswamp': 16364,
#     '#2a': 16362,
#     '#q': 16260,
#     '#coronavirus': 16255,
#     '#democrats': 16024,
#     '#patriots': 15255,
#     '#blm': 15238,
#     '#trump2020 #trump': 14973,
#     '#antifa': 14621,
#     '#fightback': 14027,
#     '#qanon #qarmy': 13621,
#     '#trump2020landslide': 13499,
#     '#alllivesmatter': 12768,
#     '#saveourchildren': 12323,
#     '#deepstate': 12061,
#     '#wwg1wga #maga': 11953,
#     '#hunterbiden': 11929}},
#   'comments': {'comments_terms': {'u': 3028961,
#     'face': 2993948,
#     'alive': 2984000,
#     'parler': 1566413,
#     'go': 1562633,
#     'follow': 1553544,
#     'see': 1549337,
#     'well': 1537899,
#     'free': 1536664,
#     'let': 1529484,
#     'speech': 1526637,
#     'free speech': 1518584,
#     'truth': 1513764,
#     'actually': 1509110,
#     'welcome': 1506815,
#     'let u': 1506584,
#     'looking': 1498621,
#     'glad': 1498457,
#     'forward': 1493617,
#     'great': 1493599,
#     'keeping': 1492859,
#     'bias': 1491477,
#     'u go': 1491061,
#     'looking forward': 1491031,
#     'glad see': 1490968,
#     'constant': 1490917,
#     'let u go': 1490872,
#     'alive well': 1490773,
#     'see parler': 1490499,
#     'parler free': 1490394,
#     'mixing': 1490379,
#     'parler free speech': 1490379,
#     'glad see parler': 1490354,
#     'well looking': 1490312,
#     'face let': 1490305,
#     'actually alive': 1490300,
#     'keeping truth': 1490300,
#     'speech actually': 1490300,
#     'face constant': 1490298,
#     'face let u': 1490298,
#     'free speech actually': 1490298,
#     'truth alive': 1490298,
#     'well looking forward': 1490297,
#     'actually alive well': 1490296,
#     'alive face': 1490296,
#     'alive face constant': 1490296,
#     'alive well looking': 1490296,
#     'bias face': 1490296,
#     'bias face let': 1490296,
#     'constant bias': 1490296},
#    'comments_hashtag': {'#parlerconcierge': 25260,
#     'best rob #parlerconcierge': 25079,
#     'rob #parlerconcierge': 25079,
#     '#trump2020': 5139,
#     '#wwg1wga': 4320,
#     '#maga': 3386,
#     '#votered': 2689,
#     '#trump2020landslide': 2569,
#     '#trumptrain2020': 1842,
#     '#kag': 1827,
#     '#parler': 1732,
#     '#stopthesteal': 1691,
#     '#trump': 1642,
#     '#democrats': 1454,
#     '#voteinperson': 1432,
#     '#maga #kag': 1374,
#     '#voteridrequired': 1362,
#     '#proofofcitizenshiptovote': 1348,
#     '#voteinperson #proofofcitizenshiptovote': 1347,
#     '#voteridrequired #trumptrain2020': 1346,
#     '#proofofcitizenshiptovote #voteridrequired': 1341,
#     '#voteinperson #proofofcitizenshiptovote #voteridrequired': 1340,
#     '#proofofcitizenshiptovote #voteridrequired #trumptrain2020': 1338,
#     '#votered #voteinperson': 1279,
#     '#votered #voteinperson #proofofcitizenshiptovote': 1278,
#     '#usa': 1203,
#     '#fakenews': 1133,
#     '#kag2020': 1123,
#     '#maga2020': 1012,
#     '#joebiden': 917,
#     '#coronavirus': 853,
#     '#': 834,
#     '#covid19': 793,
#     '#blm': 791,
#     '#deepstate': 709,
#     '#voterfraud': 705,
#     '#saveourchildren': 686,
#     '#antifa': 670,
#     '#qarmy': 662,
#     '#1': 651,
#     '#qanon': 631,
#     '#backtheblue': 621,
#     '#presidenttrumpjoinparler': 617,
#     'advocating #presidenttrumpjoinparler': 617,
#     'start advocating #presidenttrumpjoinparler': 617,
#     '#americafirst': 615,
#     '#wwg1wgaworldwide': 605,
#     '#presidenttrumpjoinparler way': 581,
#     '#presidenttrumpjoinparler way give': 581,
#     'advocating #presidenttrumpjoinparler way': 581}}},
#  'ext_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'trump': 178037,
#     'news': 90784,
#     'biden': 71472,
#     'say': 57241,
#     'democrat': 55862,
#     'u': 53020,
#     'president': 52380,
#     'video': 50902,
#     'people': 48909,
#     'right': 47464,
#     'new': 45316,
#     'one': 44454,
#     'time': 44155,
#     '#news': 42017,
#     'state': 41604,
#     'fox': 41578,
#     '#justice': 41486,
#     '#freedom': 41467,
#     '#news #justice': 41350,
#     'american': 41139,
#     'get': 39088,
#     'like': 37970,
#     'report': 37333,
#     'fox news': 37039,
#     'election': 36543,
#     'would': 36143,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     'god': 35113,
#     'coronavirus': 33785,
#     'know': 33226,
#     'joe': 33008,
#     'via': 31775,
#     'america': 31174,
#     'see': 30543,
#     'want': 29404,
#     'vote': 28370,
#     'go': 27096,
#     'twitter': 26739,
#     'president trump': 26508,
#     'day': 26388,
#     'house': 26181,
#     'need': 25834,
#     'medium': 25365,
#     'call': 24742,
#     'year': 24587,
#     'china': 24217,
#     'police': 23978,
#     '#thegreatawakening': 23897,
#     '#justice #thegreatawakening': 23579},
#    'overall_hashtags': {'#news': 42017,
#     '#justice': 41486,
#     '#freedom': 41467,
#     '#news #justice': 41350,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     '#thegreatawakening': 23897,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     '#justice #freedom': 17774,
#     '#justice #freedom #sovereignty': 17774,
#     '#news #justice #freedom': 17773,
#     '#thegreatawakening #freedom #sovereignty': 17667,
#     '#meme': 15197,
#     '#communist': 7796,
#     '#memes': 6479,
#     '#meme #memes': 6460,
#     '#closetheborder': 5915,
#     '#freedom #closetheborder': 5912,
#     '#thegreatawakening #freedom #closetheborder': 5912,
#     '#wwg1wga': 4635,
#     '#trump2020': 4322,
#     '#maga': 4131,
#     '#trump': 2598,
#     '#nickelnews': 2166,
#     '#truthisfree': 1826,
#     '#1': 1586,
#     '#americafirst': 1519,
#     '#coronavirus': 1493,
#     '#kag': 1493,
#     '#iran': 1441,
#     '#3': 1323,
#     '#2': 1319,
#     '#parler': 1283,
#     '#dobbs': 1214,
#     '#democrats': 1207,
#     '#whitehouse': 1201,
#     '#qanon': 1193,
#     '#4': 1181,
#     '#5': 1160,
#     '#6': 1148,
#     '#7': 1137,
#     '#propaganda': 1107,
#     '#8': 1077,
#     '#saveourchildren': 990,
#     '#foxnews': 909,
#     '#covid19': 890,
#     '#fakenews': 857}},
#   'posts': {'posts_terms': {'trump': 171494,
#     'news': 89057,
#     'biden': 69288,
#     'say': 53531,
#     'democrat': 52770,
#     'video': 49761,
#     'president': 49253,
#     'u': 47148,
#     'new': 43206,
#     '#news': 42017,
#     '#justice': 41478,
#     '#freedom': 41461,
#     '#news #justice': 41350,
#     'right': 41220,
#     'fox': 40820,
#     'people': 40802,
#     'american': 38952,
#     'time': 38051,
#     'state': 37954,
#     'report': 36841,
#     'fox news': 36793,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     'one': 35342,
#     'election': 34966,
#     'coronavirus': 33640,
#     'via': 31555,
#     'joe': 31421,
#     'get': 30440,
#     'god': 30207,
#     'like': 28641,
#     'america': 28461,
#     'would': 27732,
#     'vote': 25618,
#     'president trump': 25300,
#     'see': 25232,
#     'house': 25103,
#     'twitter': 25086,
#     'want': 24744,
#     'know': 24306,
#     '#thegreatawakening': 23890,
#     'medium': 23757,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     'call': 23405,
#     'day': 23296,
#     'police': 23173,
#     'china': 23063},
#    'posts_hashtags': {'#news': 42017,
#     '#justice': 41478,
#     '#freedom': 41461,
#     '#news #justice': 41350,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     '#thegreatawakening': 23890,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     '#justice #freedom': 17774,
#     '#justice #freedom #sovereignty': 17774,
#     '#news #justice #freedom': 17773,
#     '#thegreatawakening #freedom #sovereignty': 17667,
#     '#meme': 15197,
#     '#communist': 7778,
#     '#memes': 6478,
#     '#meme #memes': 6460,
#     '#closetheborder': 5915,
#     '#freedom #closetheborder': 5912,
#     '#thegreatawakening #freedom #closetheborder': 5912,
#     '#wwg1wga': 4375,
#     '#trump2020': 4141,
#     '#maga': 4052,
#     '#trump': 2551,
#     '#nickelnews': 2139,
#     '#truthisfree': 1818,
#     '#1': 1533,
#     '#coronavirus': 1491,
#     '#americafirst': 1488,
#     '#kag': 1434,
#     '#iran': 1424,
#     '#3': 1311,
#     '#2': 1305,
#     '#parler': 1263,
#     '#dobbs': 1214,
#     '#whitehouse': 1199,
#     '#qanon': 1180,
#     '#4': 1177,
#     '#democrats': 1172,
#     '#5': 1156,
#     '#6': 1145,
#     '#7': 1135,
#     '#propaganda': 1099,
#     '#8': 1077,
#     '#foxnews': 901,
#     '#covid19': 868,
#     '#fakenews': 817,
#     '#joebiden': 773}},
#   'comments': {'comments_terms': {'like': 9329,
#     'one': 9112,
#     'know': 8920,
#     'get': 8648,
#     'would': 8411,
#     'people': 8107,
#     'good': 6589,
#     'trump': 6543,
#     'exactly': 6382,
#     'right': 6244,
#     'time': 6104,
#     'u': 5872,
#     'think': 5487,
#     'need': 5408,
#     'amen': 5331,
#     'see': 5311,
#     'go': 5304,
#     'god': 4906,
#     'yes': 4903,
#     'going': 4709,
#     'want': 4660,
#     'got': 4396,
#     'thanks': 4203,
#     'never': 4105,
#     'lol': 3955,
#     'thank': 3936,
#     'year': 3876,
#     'make': 3815,
#     'cannot': 3755,
#     'say': 3710,
#     'great': 3668,
#     'state': 3650,
#     'back': 3523,
#     'agree': 3505,
#     'take': 3495,
#     'many': 3444,
#     'love': 3387,
#     'thing': 3277,
#     'way': 3246,
#     'well': 3205,
#     'look': 3131,
#     'president': 3127,
#     'day': 3092,
#     'democrat': 3092,
#     'could': 2910,
#     'even': 2861,
#     'vote': 2752,
#     'said': 2744,
#     'america': 2713,
#     'much': 2627},
#    'comments_hashtag': {'#saveourchildren': 291,
#     '#shadowgate': 260,
#     '#wwg1wga': 260,
#     '#trump2020': 181,
#     '#deepstate': 142,
#     '#chicomvirus': 118,
#     '#voteredtosaveamerica': 116,
#     '#bidencrimefamily': 102,
#     '#greatawakening': 99,
#     '#': 92,
#     '#stopthesteal': 89,
#     '#maga': 79,
#     '#tyfyi': 76,
#     '#truethevote': 75,
#     '#kag': 59,
#     '#voterfraud': 54,
#     '#1': 53,
#     '#votetrump2020': 50,
#     '#landslide2020': 49,
#     '#trump': 47,
#     '#fakenews': 40,
#     '#trump2020landslide': 39,
#     '#cruelladekamala': 37,
#     '#sethrich': 36,
#     '#democrats': 35,
#     '#islam': 35,
#     '#trojanhorse': 35,
#     '#sharialaw': 33,
#     '#china': 32,
#     '#instablock': 32,
#     '#americafirst': 31,
#     '#antifa': 31,
#     '#holdtheline': 31,
#     '#obamagate': 31,
#     '#joebiden': 30,
#     '#obamamistake': 29,
#     '#draintheswamp': 28,
#     '#biden': 27,
#     '#nickelnews': 27,
#     '#bidencheated': 26,
#     '#creepypedojoe': 26,
#     '#georgia': 26,
#     '#joementia': 26,
#     '#redpilled': 26,
#     '#soros': 26,
#     'see #shadowgate': 26,
#     'vote #trump2020': 26,
#     '#wwg1wga #greatawakening': 25,
#     '#fightback': 24,
#     '#trumpwon': 24}}}}

# %%
# serializing the term_dict

with open('top50terms#s.json', 'w') as outfile:
    json_obj = json.dumps(term_dict)
    outfile.write(json_obj)

# %%
term_dict
# Out:
# {'min_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'parler': 2616199,
#     'everyone': 2425771,
#     'looking': 2287494,
#     'forward': 2236112,
#     'joined': 2211886,
#     'looking forward': 2194244,
#     'meeting': 2193320,
#     'joined parler': 2181246,
#     'forward meeting': 2175400,
#     'parler looking': 2175205,
#     'looking forward meeting': 2175073,
#     'parler looking forward': 2174773,
#     'meeting everyone': 2174491,
#     'forward meeting everyone': 2174427,
#     'joined parler looking': 2174344,
#     'trump': 1592144,
#     'people': 1526405,
#     'like': 1213371,
#     'get': 1188364,
#     'know': 1119164,
#     'would': 1114237,
#     'u': 1074311,
#     'need': 1035396,
#     'one': 1002628,
#     'president': 901492,
#     'time': 846073,
#     'go': 756742,
#     'going': 725249,
#     'election': 717252,
#     'right': 714286,
#     'biden': 697858,
#     'think': 693403,
#     'want': 677818,
#     'see': 670639,
#     'good': 645582,
#     'vote': 636927,
#     'god': 631022,
#     'country': 619694,
#     'state': 610820,
#     'cannot': 570234,
#     'make': 569662,
#     'say': 565698,
#     'democrat': 549137,
#     'back': 542847,
#     'take': 537435,
#     'let': 528123,
#     'year': 525520,
#     'never': 521115,
#     'new': 516877,
#     'way': 509555},
#    'overall_hashtags': {'#parlerconcierge': 349842,
#     '#newuser': 213819,
#     'question #parlerconcierge': 201837,
#     'know question #parlerconcierge': 201834,
#     '#truefreespeech': 147719,
#     '#newuser #truefreespeech': 147680,
#     'enjoy #newuser': 147677,
#     'interact enjoy #newuser': 147675,
#     '#truefreespeech #parlerconcierge': 147673,
#     '#newuser #truefreespeech #parlerconcierge': 147672,
#     'enjoy #newuser #truefreespeech': 147672,
#     '#trump2020': 100129,
#     'everyone #newuser': 63558,
#     'meeting everyone #newuser': 63550,
#     '#stopthesteal': 61109,
#     '#maga': 59659,
#     '#trump': 39045,
#     '#parler': 36795,
#     '#wwg1wga': 30020,
#     '#election2020': 20238,
#     '#qanon': 18324,
#     '#electionfraud': 18019,
#     '#maga2020': 17781,
#     '#kag': 17774,
#     '#voterfraud': 16580,
#     '#freedom': 15794,
#     '#covid19': 15756,
#     '#usa': 15627,
#     '#trumptrain': 15062,
#     '#parlerusa': 13686,
#     '#blm': 13016,
#     '#america': 12465,
#     '#patriots': 12423,
#     '#fakenews': 12307,
#     '#donaldtrump': 12137,
#     '#': 11830,
#     '#draintheswamp': 11179,
#     '#americafirst': 11053,
#     '#trump2020landslide': 10683,
#     '#joebiden': 10053,
#     '#biden': 9953,
#     '#obamagate': 9938,
#     '#thegreatawakening': 9901,
#     '#truth': 9815,
#     '#meme': 9519,
#     '#wethepeople': 9505,
#     '#antifa': 9443,
#     '#democrats': 9322,
#     '#fightback': 9318,
#     '#twexit': 8825}},
#   'posts': {'posts_terms': {'parler': 2277517,
#     'everyone': 2244500,
#     'looking': 2202431,
#     'forward': 2191525,
#     'joined': 2186611,
#     'meeting': 2180521,
#     'looking forward': 2180515,
#     'joined parler': 2177131,
#     'forward meeting': 2174760,
#     'parler looking': 2174715,
#     'looking forward meeting': 2174576,
#     'parler looking forward': 2174460,
#     'meeting everyone': 2174252,
#     'forward meeting everyone': 2174221,
#     'joined parler looking': 2174190,
#     'trump': 373998,
#     'people': 292358,
#     'u': 241598,
#     'president': 218731,
#     'get': 207887,
#     'election': 201554,
#     'one': 188288,
#     'like': 187392,
#     'time': 182826,
#     'biden': 178859,
#     'need': 167529,
#     'know': 161880,
#     'would': 161409,
#     'state': 146564,
#     'vote': 143572,
#     'god': 142448,
#     'day': 139534,
#     'going': 138270,
#     'right': 134939,
#     'see': 132813,
#     'want': 131989,
#     'new': 131881,
#     'go': 125779,
#     'country': 125703,
#     'say': 120668,
#     'year': 117979,
#     'let': 115888,
#     'make': 112308,
#     'news': 112277,
#     'good': 111922,
#     'america': 111110,
#     'american': 110429,
#     'think': 108599,
#     'democrat': 105152,
#     'take': 104098},
#    'posts_hashtags': {'#trump2020': 71998,
#     '#newuser': 65781,
#     'everyone #newuser': 63557,
#     'meeting everyone #newuser': 63549,
#     '#maga': 42728,
#     '#stopthesteal': 39058,
#     '#parler': 31462,
#     '#trump': 31269,
#     '#wwg1wga': 21755,
#     '#election2020': 17779,
#     '#electionfraud': 14878,
#     '#qanon': 14839,
#     '#covid19': 14029,
#     '#maga2020': 13560,
#     '#freedom': 13480,
#     '#voterfraud': 13447,
#     '#usa': 12813,
#     '#trumptrain': 12735,
#     '#parlerusa': 12522,
#     '#kag': 10820,
#     '#donaldtrump': 10680,
#     '#america': 10248,
#     '#blm': 9534,
#     '#patriots': 9285,
#     '#fakenews': 9036,
#     '#meme': 8848,
#     '#joebiden': 8746,
#     '#thegreatawakening': 8383,
#     '#americafirst': 8286,
#     '#biden': 7946,
#     '#draintheswamp': 7675,
#     '#truth': 7425,
#     '#conservative': 7285,
#     '#democrats': 7126,
#     '#trump2020landslide': 6875,
#     '#twexit': 6745,
#     '#covid': 6604,
#     '#presidenttrump': 6590,
#     '#obamagate': 6257,
#     '#republican': 6112,
#     '#election': 6034,
#     '#antifa': 5917,
#     '#2a': 5908,
#     '#keepamericagreat': 5873,
#     '#coronavirus': 5742,
#     '#wethepeople': 5706,
#     '#parler #parlerusa': 5663,
#     '#kag2020': 5581,
#     '#twitter': 5572,
#     '#fightback': 5496}},
#   'comments': {'comments_terms': {'people': 1234047,
#     'trump': 1218146,
#     'like': 1025979,
#     'get': 980477,
#     'know': 957284,
#     'would': 952828,
#     'need': 867867,
#     'u': 832713,
#     'one': 814340,
#     'president': 682761,
#     'time': 663247,
#     'go': 630963,
#     'going': 586979,
#     'think': 584804,
#     'right': 579347,
#     'want': 545829,
#     'see': 537826,
#     'good': 533660,
#     'biden': 518999,
#     'election': 515698,
#     'country': 493991,
#     'vote': 493355,
#     'god': 488574,
#     'welcome': 475758,
#     'cannot': 470253,
#     'state': 464256,
#     'make': 457354,
#     'say': 445030,
#     'democrat': 443985,
#     'back': 441513,
#     'never': 435031,
#     'take': 433337,
#     'hope': 427487,
#     'way': 419480,
#     'let': 412235,
#     'year': 407541,
#     'american': 392188,
#     'love': 388259,
#     'new': 384996,
#     'well': 380409,
#     'thank': 372231,
#     'thing': 368074,
#     'even': 361638,
#     'america': 349668,
#     '#parlerconcierge': 349653,
#     'look': 342740,
#     'parler': 338682,
#     'enjoy': 334643,
#     'keep': 326157,
#     'yes': 321206},
#    'comments_hashtag': {'#parlerconcierge': 349653,
#     'question #parlerconcierge': 201835,
#     'know question #parlerconcierge': 201833,
#     '#newuser': 148038,
#     '#truefreespeech': 147702,
#     '#newuser #truefreespeech': 147677,
#     'enjoy #newuser': 147674,
#     'interact enjoy #newuser': 147674,
#     '#truefreespeech #parlerconcierge': 147672,
#     '#newuser #truefreespeech #parlerconcierge': 147671,
#     'enjoy #newuser #truefreespeech': 147671,
#     '#trump2020': 28131,
#     '#stopthesteal': 22051,
#     '#maga': 16931,
#     '#wwg1wga': 8265,
#     '#trump': 7776,
#     '#kag': 6954,
#     '#': 6392,
#     '#parler': 5333,
#     '#1': 5237,
#     '#maga2020': 4221,
#     '#fightback': 3822,
#     '#trump2020landslide': 3808,
#     '#wethepeople': 3799,
#     '#obamagate': 3681,
#     '#antifa': 3526,
#     '#draintheswamp': 3504,
#     '#qanon': 3485,
#     '#blm': 3482,
#     '#boycottgeorgiarunoffs': 3332,
#     '#fakenews': 3271,
#     '#electionfraud': 3141,
#     '#patriots': 3138,
#     '#voterfraud': 3133,
#     '#progressive': 3084,
#     '#resist': 2865,
#     '#usa': 2814,
#     '#americafirst': 2767,
#     '#boycottgeorgia': 2738,
#     '#election2020': 2459,
#     '#kag2020': 2451,
#     '#georgia': 2440,
#     '#truth': 2390,
#     '#holdtheline': 2354,
#     '#trumptrain': 2327,
#     '#freedom': 2314,
#     '#trump2020 #kag': 2305,
#     '#america': 2217,
#     '#saveourchildren': 2217,
#     '#democrats': 2196}}},
#  'mod_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'parler': 6060833,
#     'people': 3999635,
#     'right': 3654882,
#     'welcome': 2765502,
#     'like': 2251085,
#     'share': 1936860,
#     'good': 1917401,
#     'life': 1855014,
#     'new': 1851661,
#     'well': 1807868,
#     'work': 1791745,
#     'trump': 1788077,
#     'free': 1767157,
#     'video': 1749847,
#     'also': 1738254,
#     'thought': 1722122,
#     'fighting': 1669452,
#     'place': 1669205,
#     'opinion': 1666236,
#     'check': 1657610,
#     'liberty': 1653793,
#     'special': 1652078,
#     'constitutional': 1648218,
#     'looking': 1647086,
#     'online': 1641220,
#     'people like': 1639259,
#     'space': 1639099,
#     'spent': 1637640,
#     'adult': 1636023,
#     'shadow': 1634478,
#     'banning': 1631720,
#     'openly': 1631504,
#     'constitutional right': 1631484,
#     'express': 1631140,
#     'excited': 1630782,
#     'youtube': 1630092,
#     'ideal': 1628213,
#     'shadow banning': 1626390,
#     'like parler': 1626064,
#     'accepts': 1625543,
#     'godgiven': 1625472,
#     'adult life': 1625034,
#     'page': 1624906,
#     'right express': 1624878,
#     'thought opinion': 1624872,
#     'special people': 1624850,
#     'throttling': 1624845,
#     'life fighting': 1624819,
#     'fighting liberty': 1624782,
#     'express thought': 1624747},
#    'overall_hashtags': {'#trump2020': 125902,
#     '#maga': 98509,
#     '#stopthesteal': 64053,
#     '#trump': 63432,
#     '#parler': 59063,
#     '#wwg1wga': 57675,
#     '#qanon': 38218,
#     '#kag': 37933,
#     '#maga2020': 35228,
#     '#usa': 33460,
#     '#patriots': 29922,
#     '#covid19': 28390,
#     '#trumptrain': 27174,
#     '#electionfraud': 27095,
#     '#americafirst': 26828,
#     '#voterfraud': 26786,
#     '#election2020': 26541,
#     '#parlerusa': 25371,
#     '#thegreatawakening': 25244,
#     '#obamagate': 25210,
#     '#donaldtrump': 24715,
#     '#freedom': 24705,
#     '#blm': 24618,
#     '#fakenews': 23507,
#     '#wethepeople': 22632,
#     '#democrats': 22486,
#     '#joebiden': 22413,
#     '#draintheswamp': 22240,
#     '#america': 22191,
#     '#news': 22123,
#     '#meme': 21036,
#     '#kag2020': 20157,
#     '#truth': 19908,
#     '#antifa': 19430,
#     '#biden': 18412,
#     '#wakeupamerica': 18146,
#     '#fightback': 17727,
#     '#backtheblue': 17437,
#     '#2a': 17393,
#     '#maga #kag': 16839,
#     '#deepstate': 16600,
#     '#presidenttrump': 16356,
#     '#twexit': 16157,
#     '#godwins': 15352,
#     '#trump2020landslide': 15333,
#     '#q': 15099,
#     '#covid': 14749,
#     '#savethechildren': 14723,
#     '#coronavirus': 14398,
#     '#keepamericagreat': 14280}},
#   'posts': {'posts_terms': {'trump': 457012,
#     'people': 287732,
#     'u': 238776,
#     'biden': 226824,
#     'president': 220788,
#     'election': 208187,
#     'get': 197013,
#     'one': 195364,
#     'like': 178840,
#     'time': 178017,
#     'state': 170116,
#     'would': 162114,
#     'democrat': 161201,
#     'news': 159955,
#     'know': 156446,
#     'vote': 156121,
#     'right': 152089,
#     'say': 149574,
#     'need': 146420,
#     'god': 136711,
#     'want': 133901,
#     'america': 133889,
#     'american': 133619,
#     'going': 128993,
#     'new': 128477,
#     'day': 127421,
#     'go': 123373,
#     'see': 116557,
#     'country': 112816,
#     'year': 110496,
#     'make': 109863,
#     'think': 107190,
#     'good': 106691,
#     'take': 104903,
#     '#trump2020': 102279,
#     'life': 100564,
#     'let': 100075,
#     'back': 99949,
#     'joe': 98051,
#     'medium': 93061,
#     'video': 91822,
#     'cannot': 90233,
#     'president trump': 88314,
#     'never': 87139,
#     'fraud': 84605,
#     'way': 83834,
#     'today': 82636,
#     'thing': 81639,
#     '#maga': 80916,
#     'watch': 80242},
#    'posts_hashtags': {'#trump2020': 102279,
#     '#maga': 80916,
#     '#trump': 55624,
#     '#stopthesteal': 52084,
#     '#parler': 50193,
#     '#wwg1wga': 45901,
#     '#qanon': 34383,
#     '#kag': 32299,
#     '#covid19': 26061,
#     '#election2020': 24717,
#     '#parlerusa': 24329,
#     '#electionfraud': 24057,
#     '#voterfraud': 23836,
#     '#maga2020': 23620,
#     '#americafirst': 22998,
#     '#usa': 22813,
#     '#thegreatawakening': 22535,
#     '#trumptrain': 22458,
#     '#patriots': 22147,
#     '#freedom': 21384,
#     '#news': 21065,
#     '#fakenews': 20914,
#     '#joebiden': 20740,
#     '#democrats': 20275,
#     '#meme': 19891,
#     '#donaldtrump': 19591,
#     '#blm': 19222,
#     '#draintheswamp': 18696,
#     '#truth': 18048,
#     '#america': 17962,
#     '#obamagate': 17644,
#     '#biden': 16958,
#     '#kag2020': 16809,
#     '#antifa': 16513,
#     '#maga #kag': 14782,
#     '#wakeupamerica': 14705,
#     '#deepstate': 14326,
#     '#fightback': 13688,
#     '#covid': 13639,
#     '#coronavirus': 13633,
#     '#keepamericagreat': 13501,
#     '#republican': 13326,
#     '#politics': 13035,
#     '#q': 13016,
#     '#election': 12989,
#     '#trump2020landslide': 12874,
#     '#presidenttrump': 12677,
#     '#qarmy': 12664,
#     '#conservative': 12245,
#     '#godwins': 12199}},
#   'comments': {'comments_terms': {'parler': 5993788,
#     'people': 3711903,
#     'right': 3502793,
#     'welcome': 2753664,
#     'like': 2072245,
#     'share': 1900095,
#     'good': 1810710,
#     'life': 1754450,
#     'well': 1744800,
#     'work': 1734941,
#     'new': 1723184,
#     'free': 1693074,
#     'thought': 1686985,
#     'also': 1683840,
#     'video': 1658025,
#     'fighting': 1653550,
#     'opinion': 1651846,
#     'constitutional': 1638844,
#     'liberty': 1638787,
#     'special': 1638019,
#     'place': 1637303,
#     'people like': 1635554,
#     'space': 1633013,
#     'adult': 1631948,
#     'spent': 1631942,
#     'online': 1631212,
#     'shadow': 1630665,
#     'constitutional right': 1629060,
#     'banning': 1628934,
#     'openly': 1628275,
#     'express': 1628070,
#     'excited': 1627750,
#     'ideal': 1626910,
#     'shadow banning': 1626146,
#     'like parler': 1625554,
#     'godgiven': 1625104,
#     'accepts': 1625068,
#     'adult life': 1624929,
#     'right express': 1624826,
#     'special people': 1624800,
#     'thought opinion': 1624788,
#     'throttling': 1624754,
#     'life fighting': 1624748,
#     'fighting liberty': 1624725,
#     'express thought': 1624721,
#     'new space': 1624692,
#     'excited new': 1624690,
#     'share work': 1624689,
#     'banning free': 1624688,
#     'work special': 1624682},
#    'comments_hashtag': {'#trump2020': 23623,
#     '#maga': 17593,
#     '#stopthesteal': 11969,
#     '#wwg1wga': 11774,
#     '#maga2020': 11608,
#     '#usa': 10647,
#     '#wethepeople': 10531,
#     '#parler': 8870,
#     '#trump': 7808,
#     '#patriots': 7775,
#     '#obamagate': 7566,
#     '#treason': 7155,
#     '#backtheblue': 6288,
#     '#usa usa': 6248,
#     '#usa usa usa': 6065,
#     '#2a': 5679,
#     '#kag': 5634,
#     '#blm': 5396,
#     '#ccp': 5354,
#     '#twexit': 5298,
#     '#chicanosfortrump': 5135,
#     '#donaldtrump': 5124,
#     '#trumptrain': 4716,
#     '#americans': 4474,
#     '#america': 4229,
#     '#1a': 4178,
#     '#fightback': 4039,
#     '#maga #maga2020': 3900,
#     'usa #chicanosfortrump': 3866,
#     'usa usa #chicanosfortrump': 3866,
#     '#qanon': 3835,
#     '#americafirst': 3830,
#     '#presidenttrump': 3679,
#     '#draintheswamp': 3544,
#     '#savethechildren': 3470,
#     '#wakeupamerica': 3441,
#     '#coupdetat': 3439,
#     '#novaccineforme': 3365,
#     '#kag2020': 3348,
#     '#walkaway': 3334,
#     '#freedom': 3321,
#     '#godwins': 3153,
#     '#dnc': 3102,
#     '#traitors': 3098,
#     '#electionfraud': 3038,
#     '#americans #patriots': 3005,
#     '#voterfraud': 2950,
#     '#': 2940,
#     '#dominion': 2925,
#     '#antifa': 2917}}},
#  'ver_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'u': 3209235,
#     'face': 3024780,
#     'alive': 2989390,
#     'go': 1658236,
#     'see': 1632660,
#     'free': 1609451,
#     'follow': 1596330,
#     'parler': 1593269,
#     'let': 1592652,
#     'well': 1581435,
#     'truth': 1561164,
#     'speech': 1551962,
#     'great': 1544039,
#     'let u': 1533814,
#     'actually': 1528219,
#     'free speech': 1524897,
#     'welcome': 1515480,
#     'looking': 1511969,
#     'forward': 1502951,
#     'glad': 1501880,
#     'keeping': 1497707,
#     'bias': 1496334,
#     'looking forward': 1492927,
#     'u go': 1492626,
#     'constant': 1492309,
#     'let u go': 1492123,
#     'glad see': 1491293,
#     'alive well': 1491197,
#     'see parler': 1490607,
#     'mixing': 1490555,
#     'parler free': 1490529,
#     'parler free speech': 1490498,
#     'glad see parler': 1490362,
#     'face let': 1490338,
#     'well looking': 1490331,
#     'keeping truth': 1490311,
#     'speech actually': 1490311,
#     'face let u': 1490310,
#     'actually alive': 1490307,
#     'face constant': 1490304,
#     'free speech actually': 1490303,
#     'truth alive': 1490302,
#     'alive face': 1490299,
#     'bias face': 1490298,
#     'constant bias': 1490298,
#     'well looking forward': 1490298,
#     'actually alive well': 1490297,
#     'alive face constant': 1490296,
#     'alive well looking': 1490296,
#     'bias face let': 1490296},
#    'overall_hashtags': {'#trump2020': 90277,
#     '#maga': 78037,
#     '#wwg1wga': 54211,
#     '#trump': 53975,
#     '#parler': 44965,
#     '#qanon': 42065,
#     '#kag': 41067,
#     '#stopthesteal': 39131,
#     '#usa': 30604,
#     '#meme': 29768,
#     '#maga #kag': 25733,
#     '#parlerconcierge': 25271,
#     'best rob #parlerconcierge': 25079,
#     'rob #parlerconcierge': 25079,
#     '#freedom': 24030,
#     '#america': 23084,
#     '#news': 22909,
#     '#memes': 22858,
#     '#fakenews': 22358,
#     '#americafirst': 22119,
#     '#covid19': 21779,
#     '#qarmy': 21643,
#     '#electionfraud': 20857,
#     '#keepamericagreat': 20387,
#     '#joebiden': 20345,
#     '#thegreatawakening': 20227,
#     '#voterfraud': 19267,
#     '#republican': 18446,
#     '#wethepeople': 18307,
#     '#bluelivesmatter': 18137,
#     '#maga2020': 17715,
#     '#parlerusa': 17658,
#     '#democrats': 17478,
#     '#trumptrain': 17440,
#     '#coronavirus': 17108,
#     '#donaldtrump': 17057,
#     '#obamagate': 16935,
#     '#draintheswamp': 16887,
#     '#2a': 16874,
#     '#teamtrump': 16751,
#     '#q': 16734,
#     '#trump2020landslide': 16068,
#     '#blm': 16029,
#     '#patriots': 15676,
#     '#antifa': 15291,
#     '#trump2020 #trump': 15052,
#     '#fightback': 14538,
#     '#qanon #qarmy': 13815,
#     '#saveourchildren': 13009,
#     '#alllivesmatter': 12993}},
#   'posts': {'posts_terms': {'trump': 518231,
#     'biden': 236391,
#     'news': 213938,
#     'president': 209183,
#     'people': 203052,
#     'democrat': 187359,
#     'u': 180274,
#     'election': 170712,
#     'say': 156515,
#     'state': 156511,
#     'one': 147890,
#     'time': 142954,
#     'right': 142831,
#     'get': 140920,
#     'new': 135531,
#     'vote': 133589,
#     'american': 131856,
#     'like': 129713,
#     'would': 123111,
#     'america': 119152,
#     'video': 110495,
#     'know': 109278,
#     'joe': 105337,
#     'want': 100969,
#     'day': 98828,
#     'fox': 97369,
#     'go': 95603,
#     'president trump': 95451,
#     'need': 93301,
#     'year': 89848,
#     'going': 87661,
#     'god': 86946,
#     'medium': 85966,
#     'police': 85221,
#     '#trump2020': 85138,
#     'back': 84109,
#     'life': 83639,
#     'fox news': 83424,
#     'make': 83366,
#     'see': 83323,
#     '2020': 83007,
#     'black': 81903,
#     'watch': 79639,
#     'country': 79210,
#     'take': 77514,
#     'china': 76244,
#     '#maga': 74651,
#     'good': 74494,
#     'white': 73121,
#     'free': 72787},
#    'posts_hashtags': {'#trump2020': 85138,
#     '#maga': 74651,
#     '#trump': 52333,
#     '#wwg1wga': 49891,
#     '#parler': 43233,
#     '#qanon': 41434,
#     '#kag': 39240,
#     '#stopthesteal': 37440,
#     '#meme': 29502,
#     '#usa': 29401,
#     '#maga #kag': 24359,
#     '#freedom': 23621,
#     '#news': 22843,
#     '#america': 22703,
#     '#memes': 22676,
#     '#americafirst': 21504,
#     '#fakenews': 21225,
#     '#covid19': 20986,
#     '#qarmy': 20981,
#     '#electionfraud': 20545,
#     '#keepamericagreat': 19826,
#     '#thegreatawakening': 19768,
#     '#joebiden': 19428,
#     '#voterfraud': 18562,
#     '#republican': 18141,
#     '#bluelivesmatter': 17939,
#     '#wethepeople': 17902,
#     '#parlerusa': 17535,
#     '#trumptrain': 17092,
#     '#donaldtrump': 16946,
#     '#maga2020': 16703,
#     '#obamagate': 16394,
#     '#teamtrump': 16376,
#     '#draintheswamp': 16364,
#     '#2a': 16362,
#     '#q': 16260,
#     '#coronavirus': 16255,
#     '#democrats': 16024,
#     '#patriots': 15255,
#     '#blm': 15238,
#     '#trump2020 #trump': 14973,
#     '#antifa': 14621,
#     '#fightback': 14027,
#     '#qanon #qarmy': 13621,
#     '#trump2020landslide': 13499,
#     '#alllivesmatter': 12768,
#     '#saveourchildren': 12323,
#     '#deepstate': 12061,
#     '#wwg1wga #maga': 11953,
#     '#hunterbiden': 11929}},
#   'comments': {'comments_terms': {'u': 3028961,
#     'face': 2993948,
#     'alive': 2984000,
#     'parler': 1566413,
#     'go': 1562633,
#     'follow': 1553544,
#     'see': 1549337,
#     'well': 1537899,
#     'free': 1536664,
#     'let': 1529484,
#     'speech': 1526637,
#     'free speech': 1518584,
#     'truth': 1513764,
#     'actually': 1509110,
#     'welcome': 1506815,
#     'let u': 1506584,
#     'looking': 1498621,
#     'glad': 1498457,
#     'forward': 1493617,
#     'great': 1493599,
#     'keeping': 1492859,
#     'bias': 1491477,
#     'u go': 1491061,
#     'looking forward': 1491031,
#     'glad see': 1490968,
#     'constant': 1490917,
#     'let u go': 1490872,
#     'alive well': 1490773,
#     'see parler': 1490499,
#     'parler free': 1490394,
#     'mixing': 1490379,
#     'parler free speech': 1490379,
#     'glad see parler': 1490354,
#     'well looking': 1490312,
#     'face let': 1490305,
#     'actually alive': 1490300,
#     'keeping truth': 1490300,
#     'speech actually': 1490300,
#     'face constant': 1490298,
#     'face let u': 1490298,
#     'free speech actually': 1490298,
#     'truth alive': 1490298,
#     'well looking forward': 1490297,
#     'actually alive well': 1490296,
#     'alive face': 1490296,
#     'alive face constant': 1490296,
#     'alive well looking': 1490296,
#     'bias face': 1490296,
#     'bias face let': 1490296,
#     'constant bias': 1490296},
#    'comments_hashtag': {'#parlerconcierge': 25260,
#     'best rob #parlerconcierge': 25079,
#     'rob #parlerconcierge': 25079,
#     '#trump2020': 5139,
#     '#wwg1wga': 4320,
#     '#maga': 3386,
#     '#votered': 2689,
#     '#trump2020landslide': 2569,
#     '#trumptrain2020': 1842,
#     '#kag': 1827,
#     '#parler': 1732,
#     '#stopthesteal': 1691,
#     '#trump': 1642,
#     '#democrats': 1454,
#     '#voteinperson': 1432,
#     '#maga #kag': 1374,
#     '#voteridrequired': 1362,
#     '#proofofcitizenshiptovote': 1348,
#     '#voteinperson #proofofcitizenshiptovote': 1347,
#     '#voteridrequired #trumptrain2020': 1346,
#     '#proofofcitizenshiptovote #voteridrequired': 1341,
#     '#voteinperson #proofofcitizenshiptovote #voteridrequired': 1340,
#     '#proofofcitizenshiptovote #voteridrequired #trumptrain2020': 1338,
#     '#votered #voteinperson': 1279,
#     '#votered #voteinperson #proofofcitizenshiptovote': 1278,
#     '#usa': 1203,
#     '#fakenews': 1133,
#     '#kag2020': 1123,
#     '#maga2020': 1012,
#     '#joebiden': 917,
#     '#coronavirus': 853,
#     '#': 834,
#     '#covid19': 793,
#     '#blm': 791,
#     '#deepstate': 709,
#     '#voterfraud': 705,
#     '#saveourchildren': 686,
#     '#antifa': 670,
#     '#qarmy': 662,
#     '#1': 651,
#     '#qanon': 631,
#     '#backtheblue': 621,
#     '#presidenttrumpjoinparler': 617,
#     'advocating #presidenttrumpjoinparler': 617,
#     'start advocating #presidenttrumpjoinparler': 617,
#     '#americafirst': 615,
#     '#wwg1wgaworldwide': 605,
#     '#presidenttrumpjoinparler way': 581,
#     '#presidenttrumpjoinparler way give': 581,
#     'advocating #presidenttrumpjoinparler way': 581}}},
#  'ext_act_lang_filtered_pre_proc.ndjson': {'overall': {'overall_terms': {'trump': 178037,
#     'news': 90784,
#     'biden': 71472,
#     'say': 57241,
#     'democrat': 55862,
#     'u': 53020,
#     'president': 52380,
#     'video': 50902,
#     'people': 48909,
#     'right': 47464,
#     'new': 45316,
#     'one': 44454,
#     'time': 44155,
#     '#news': 42017,
#     'state': 41604,
#     'fox': 41578,
#     '#justice': 41486,
#     '#freedom': 41467,
#     '#news #justice': 41350,
#     'american': 41139,
#     'get': 39088,
#     'like': 37970,
#     'report': 37333,
#     'fox news': 37039,
#     'election': 36543,
#     'would': 36143,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     'god': 35113,
#     'coronavirus': 33785,
#     'know': 33226,
#     'joe': 33008,
#     'via': 31775,
#     'america': 31174,
#     'see': 30543,
#     'want': 29404,
#     'vote': 28370,
#     'go': 27096,
#     'twitter': 26739,
#     'president trump': 26508,
#     'day': 26388,
#     'house': 26181,
#     'need': 25834,
#     'medium': 25365,
#     'call': 24742,
#     'year': 24587,
#     'china': 24217,
#     'police': 23978,
#     '#thegreatawakening': 23897,
#     '#justice #thegreatawakening': 23579},
#    'overall_hashtags': {'#news': 42017,
#     '#justice': 41486,
#     '#freedom': 41467,
#     '#news #justice': 41350,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     '#thegreatawakening': 23897,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     '#justice #freedom': 17774,
#     '#justice #freedom #sovereignty': 17774,
#     '#news #justice #freedom': 17773,
#     '#thegreatawakening #freedom #sovereignty': 17667,
#     '#meme': 15197,
#     '#communist': 7796,
#     '#memes': 6479,
#     '#meme #memes': 6460,
#     '#closetheborder': 5915,
#     '#freedom #closetheborder': 5912,
#     '#thegreatawakening #freedom #closetheborder': 5912,
#     '#wwg1wga': 4635,
#     '#trump2020': 4322,
#     '#maga': 4131,
#     '#trump': 2598,
#     '#nickelnews': 2166,
#     '#truthisfree': 1826,
#     '#1': 1586,
#     '#americafirst': 1519,
#     '#coronavirus': 1493,
#     '#kag': 1493,
#     '#iran': 1441,
#     '#3': 1323,
#     '#2': 1319,
#     '#parler': 1283,
#     '#dobbs': 1214,
#     '#democrats': 1207,
#     '#whitehouse': 1201,
#     '#qanon': 1193,
#     '#4': 1181,
#     '#5': 1160,
#     '#6': 1148,
#     '#7': 1137,
#     '#propaganda': 1107,
#     '#8': 1077,
#     '#saveourchildren': 990,
#     '#foxnews': 909,
#     '#covid19': 890,
#     '#fakenews': 857}},
#   'posts': {'posts_terms': {'trump': 171494,
#     'news': 89057,
#     'biden': 69288,
#     'say': 53531,
#     'democrat': 52770,
#     'video': 49761,
#     'president': 49253,
#     'u': 47148,
#     'new': 43206,
#     '#news': 42017,
#     '#justice': 41478,
#     '#freedom': 41461,
#     '#news #justice': 41350,
#     'right': 41220,
#     'fox': 40820,
#     'people': 40802,
#     'american': 38952,
#     'time': 38051,
#     'state': 37954,
#     'report': 36841,
#     'fox news': 36793,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     'one': 35342,
#     'election': 34966,
#     'coronavirus': 33640,
#     'via': 31555,
#     'joe': 31421,
#     'get': 30440,
#     'god': 30207,
#     'like': 28641,
#     'america': 28461,
#     'would': 27732,
#     'vote': 25618,
#     'president trump': 25300,
#     'see': 25232,
#     'house': 25103,
#     'twitter': 25086,
#     'want': 24744,
#     'know': 24306,
#     '#thegreatawakening': 23890,
#     'medium': 23757,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     'call': 23405,
#     'day': 23296,
#     'police': 23173,
#     'china': 23063},
#    'posts_hashtags': {'#news': 42017,
#     '#justice': 41478,
#     '#freedom': 41461,
#     '#news #justice': 41350,
#     '#sovereignty': 35442,
#     '#freedom #sovereignty': 35441,
#     '#thegreatawakening': 23890,
#     '#justice #thegreatawakening': 23579,
#     '#justice #thegreatawakening #freedom': 23579,
#     '#thegreatawakening #freedom': 23579,
#     '#news #justice #thegreatawakening': 23577,
#     '#justice #freedom': 17774,
#     '#justice #freedom #sovereignty': 17774,
#     '#news #justice #freedom': 17773,
#     '#thegreatawakening #freedom #sovereignty': 17667,
#     '#meme': 15197,
#     '#communist': 7778,
#     '#memes': 6478,
#     '#meme #memes': 6460,
#     '#closetheborder': 5915,
#     '#freedom #closetheborder': 5912,
#     '#thegreatawakening #freedom #closetheborder': 5912,
#     '#wwg1wga': 4375,
#     '#trump2020': 4141,
#     '#maga': 4052,
#     '#trump': 2551,
#     '#nickelnews': 2139,
#     '#truthisfree': 1818,
#     '#1': 1533,
#     '#coronavirus': 1491,
#     '#americafirst': 1488,
#     '#kag': 1434,
#     '#iran': 1424,
#     '#3': 1311,
#     '#2': 1305,
#     '#parler': 1263,
#     '#dobbs': 1214,
#     '#whitehouse': 1199,
#     '#qanon': 1180,
#     '#4': 1177,
#     '#democrats': 1172,
#     '#5': 1156,
#     '#6': 1145,
#     '#7': 1135,
#     '#propaganda': 1099,
#     '#8': 1077,
#     '#foxnews': 901,
#     '#covid19': 868,
#     '#fakenews': 817,
#     '#joebiden': 773}},
#   'comments': {'comments_terms': {'like': 9329,
#     'one': 9112,
#     'know': 8920,
#     'get': 8648,
#     'would': 8411,
#     'people': 8107,
#     'good': 6589,
#     'trump': 6543,
#     'exactly': 6382,
#     'right': 6244,
#     'time': 6104,
#     'u': 5872,
#     'think': 5487,
#     'need': 5408,
#     'amen': 5331,
#     'see': 5311,
#     'go': 5304,
#     'god': 4906,
#     'yes': 4903,
#     'going': 4709,
#     'want': 4660,
#     'got': 4396,
#     'thanks': 4203,
#     'never': 4105,
#     'lol': 3955,
#     'thank': 3936,
#     'year': 3876,
#     'make': 3815,
#     'cannot': 3755,
#     'say': 3710,
#     'great': 3668,
#     'state': 3650,
#     'back': 3523,
#     'agree': 3505,
#     'take': 3495,
#     'many': 3444,
#     'love': 3387,
#     'thing': 3277,
#     'way': 3246,
#     'well': 3205,
#     'look': 3131,
#     'president': 3127,
#     'day': 3092,
#     'democrat': 3092,
#     'could': 2910,
#     'even': 2861,
#     'vote': 2752,
#     'said': 2744,
#     'america': 2713,
#     'much': 2627},
#    'comments_hashtag': {'#saveourchildren': 291,
#     '#shadowgate': 260,
#     '#wwg1wga': 260,
#     '#trump2020': 181,
#     '#deepstate': 142,
#     '#chicomvirus': 118,
#     '#voteredtosaveamerica': 116,
#     '#bidencrimefamily': 102,
#     '#greatawakening': 99,
#     '#': 92,
#     '#stopthesteal': 89,
#     '#maga': 79,
#     '#tyfyi': 76,
#     '#truethevote': 75,
#     '#kag': 59,
#     '#voterfraud': 54,
#     '#1': 53,
#     '#votetrump2020': 50,
#     '#landslide2020': 49,
#     '#trump': 47,
#     '#fakenews': 40,
#     '#trump2020landslide': 39,
#     '#cruelladekamala': 37,
#     '#sethrich': 36,
#     '#democrats': 35,
#     '#islam': 35,
#     '#trojanhorse': 35,
#     '#sharialaw': 33,
#     '#china': 32,
#     '#instablock': 32,
#     '#americafirst': 31,
#     '#antifa': 31,
#     '#holdtheline': 31,
#     '#obamagate': 31,
#     '#joebiden': 30,
#     '#obamamistake': 29,
#     '#draintheswamp': 28,
#     '#biden': 27,
#     '#nickelnews': 27,
#     '#bidencheated': 26,
#     '#creepypedojoe': 26,
#     '#georgia': 26,
#     '#joementia': 26,
#     '#redpilled': 26,
#     '#soros': 26,
#     'see #shadowgate': 26,
#     'vote #trump2020': 26,
#     '#wwg1wga #greatawakening': 25,
#     '#fightback': 24,
#     '#trumpwon': 24}}}}

# %%
# runnign through the files and return a top level dictionary

# %%
df = pd.read_json(file, lines=True)

# %%
# %%time
# this is the top n freqs for posts

# vectorizing the posts
# initializing the vectorizer
# setting min doc freq to 1 release b/c of the small size of the corpus (not setting max df b/c of a fear of losing things)
vectorizer = CountVectorizer(min_df=1, preprocessor=dummy_func, tokenizer=cust_tokenizer, ngram_range=(1,3))
# applying the vectorizer to posts
tf = vectorizer.fit_transform(df[df["t"]=="p"]["bo"])

# pulling the terms
tf_feature_names = vectorizer.get_feature_names()

# pulling the term counts
term_counts = np.asarray(tf.sum(axis=0))[0]

# making a dictionary w/terms and term counts
term_freqs = dict(zip(tf_feature_names, term_counts))

# making a dict w/terms and term counts for hashtags within this
hashtag_freqs = {key:value for (key, value) in term_freqs.items() if "#" in key}

# looks at the top 50 terms to be found here overall
# takes advantage of the return type of sorted (a list of tuples) and takes a slice before making a dict from that
overall = dict((sorted(term_freqs.items(), key=lambda item: item[1],reverse=True))[0:50])

# findign the top 50 terms that are hashtags
hashtags = dict((sorted(hashtag_freqs.items(), key=lambda item: item[1],reverse=True))[0:50])
# Out:
# CPU times: total: 1min 49s
# Wall time: 1min 49s

# %%
# %%time
term_list = vect_tf(df, 50)
# Out:
# CPU times: total: 2min 11s
# Wall time: 2min 11s

# %%
term_list
# Out:
# [{'trump': 178037,
#   'news': 90784,
#   'biden': 71472,
#   'say': 57241,
#   'democrat': 55862,
#   'u': 53020,
#   'president': 52380,
#   'video': 50902,
#   'people': 48909,
#   'right': 47464,
#   'new': 45316,
#   'one': 44454,
#   'time': 44155,
#   '#news': 42017,
#   'state': 41604,
#   'fox': 41578,
#   '#justice': 41486,
#   '#freedom': 41467,
#   '#news #justice': 41350,
#   'american': 41139,
#   'get': 39088,
#   'like': 37970,
#   'report': 37333,
#   'fox news': 37039,
#   'election': 36543,
#   'would': 36143,
#   '#sovereignty': 35442,
#   '#freedom #sovereignty': 35441,
#   'god': 35113,
#   'coronavirus': 33785,
#   'know': 33226,
#   'joe': 33008,
#   'via': 31775,
#   'america': 31174,
#   'see': 30543,
#   'want': 29404,
#   'vote': 28370,
#   'go': 27096,
#   'twitter': 26739,
#   'president trump': 26508,
#   'day': 26388,
#   'house': 26181,
#   'need': 25834,
#   'medium': 25365,
#   'call': 24742,
#   'year': 24587,
#   'china': 24217,
#   'police': 23978,
#   '#thegreatawakening': 23897,
#   '#justice #thegreatawakening': 23579},
#  {'#news': 42017,
#   '#justice': 41486,
#   '#freedom': 41467,
#   '#news #justice': 41350,
#   '#sovereignty': 35442,
#   '#freedom #sovereignty': 35441,
#   '#thegreatawakening': 23897,
#   '#justice #thegreatawakening': 23579,
#   '#justice #thegreatawakening #freedom': 23579,
#   '#thegreatawakening #freedom': 23579,
#   '#news #justice #thegreatawakening': 23577,
#   '#justice #freedom': 17774,
#   '#justice #freedom #sovereignty': 17774,
#   '#news #justice #freedom': 17773,
#   '#thegreatawakening #freedom #sovereignty': 17667,
#   '#meme': 15197,
#   '#communist': 7796,
#   '#memes': 6479,
#   '#meme #memes': 6460,
#   '#closetheborder': 5915,
#   '#freedom #closetheborder': 5912,
#   '#thegreatawakening #freedom #closetheborder': 5912,
#   '#wwg1wga': 4635,
#   '#trump2020': 4322,
#   '#maga': 4131,
#   '#trump': 2598,
#   '#nickelnews': 2166,
#   '#truthisfree': 1826,
#   '#1': 1586,
#   '#americafirst': 1519,
#   '#coronavirus': 1493,
#   '#kag': 1493,
#   '#iran': 1441,
#   '#3': 1323,
#   '#2': 1319,
#   '#parler': 1283,
#   '#dobbs': 1214,
#   '#democrats': 1207,
#   '#whitehouse': 1201,
#   '#qanon': 1193,
#   '#4': 1181,
#   '#5': 1160,
#   '#6': 1148,
#   '#7': 1137,
#   '#propaganda': 1107,
#   '#8': 1077,
#   '#saveourchildren': 990,
#   '#foxnews': 909,
#   '#covid19': 890,
#   '#fakenews': 857}]

# %%
# this code pulls the top n term freqs overall

# vectorizing the posts
# initializing the vectorizer
# setting min doc freq to 1 release b/c of the small size of the corpus (not setting max df b/c of a fear of losing things)
vectorizer = CountVectorizer(min_df=1, ngram_range=(1,3))

# applying the vectorizer
tf = vectorizer.fit_transform(df["bo"])

# pulling the terms
tf_feature_names = vectorizer.get_feature_names()

# pulling the term counts
term_counts = np.asarray(tf.sum(axis=0))[0]

# making a dictionary w/terms and term counts
term_freqs = dict(zip(tf_feature_names, term_counts))

# looks at the top 50 terms to be found here overall
# takes advantage of the return type of sorted (a list of tuples) and takes a slice before making a dict from that
dict((sorted(term_freqs.items(), key=lambda item: item[1],reverse=True))[0:50])
# Out:
# CPU times: total: 1min 43s
# Wall time: 1min 43s

# %%
# this is the test to check if I'm competent or not

# %%
# Out:
# {'00': 13,
#  '00 anyway': 1,
#  '00 anyway flushed': 1,
#  '00 buckshot': 4,
#  '00 buckshot antifaus': 1,
#  '00 buckshot messy': 1,
#  '00 buckshot recommended': 1,
#  '00 buckshot slug': 1,
#  '00 est': 1,
#  '00 est fucking': 1,
#  '00 got': 1,
#  '00 got get': 1,
#  '00 major': 1,
#  '00 major presidential': 1,
#  '00 morning': 1,
#  '00 morning goonna': 1,
#  '00 pm': 1,
#  '00 pm wall': 1,
#  '00 question': 1,
#  '00 question never': 1,
#  '00 stop': 1,
#  '00 stop steal': 1,
#  '00 tariff': 1,
#  '00 tariff tariff': 1,
#  '000': 35,
#  '000 000': 1,
#  '000 000 people': 1,
#  '000 1000': 1,
#  '000 ballot': 1,
#  '000 ballot brought': 1,
#  '000 black': 1,
#  '000 black black': 1,
#  '000 buy': 1,
#  '000 buy photo': 1,
#  '000 cancer': 2,
#  '000 cancer research': 2,
#  '000 coincidentally': 1,
#  '000 coincidentally buried': 1,
#  '000 coronavirus': 2,
#  '000 coronavirus 700': 1,
#  '000 coronavirus death': 1,
#  '000 freebreathers': 1,
#  '000 guess': 1,
#  '000 guess one': 1,
#  '000 infected': 1,
#  '000 infected coronavirus': 1,
#  '000 inhab': 1,
#  '000 inhab warsaw': 1,
#  '000 innocent': 2,
#  '000 innocent people': 2,
#  '000 isi': 2,
#  '000 isi fighter': 1,
#  '000 isi member': 1,
#  '000 km': 1,
#  '000 km year': 1,
#  '000 kung': 1,
#  '000 kung flu': 1,
#  '000 number': 3,
#  '000 number 32': 3,
#  '000 people': 2,
#  '000 people life': 1,
#  '000 people provided': 1,
#  '000 pole': 1,
#  '000 pole lost': 1,
#  '000 polish': 1,
#  '000 polish soldier': 1,
#  '000 reporting': 1,
#  '000 reporting go': 1,
#  '000 somali': 1,
#  '000 somali mn': 1,
#  '000 sub': 1,
#  '000 trump': 1,
#  '000 trump russia': 1,
#  '0000': 2,
#  '0000 gmt': 1,
#  '0000 gmt tuesday': 1,
#  '0000 parrot': 1,
#  '0000 parrot governor': 1,
#  '00000001': 1,
#  '00000001 athlete': 1,
#  '0000001': 1,
#  '000000189': 1,
#  '000000189 52000000': 1,
#  '000000189 52000000 democracy': 1,
#  '0000017': 1,
#  '0000017 population': 1,
#  '000003': 1,
#  '000003 percent': 1,
#  '000003 percent population': 1,
#  '000006': 1,
#  '000006 incidence': 1,
#  '000006 incidence 903': 1,
#  '00000623': 1,
#  '00000623 au': 1,
#  '00000623 au 319': 1,
#  '00001': 2,
#  '00001 lethality': 1,
#  '00001 lethality rate': 1,
#  '00001 techno': 1,
#  '00001 techno nazi': 1,
#  '0000355': 1,
#  '0000355 almost': 1,
#  '0000355 almost 410ths': 1,
#  '00004': 1,
#  '00004 trump': 1,
#  '00004 trump last': 1,
#  '000047': 1,
#  '000047 gmt': 1,
#  '000047 gmt read': 1,
#  '000056': 1,
#  '000056 died': 1,
#  '000056 died sweden': 1,
#  '00006': 1,
#  '00006 salary': 1,
#  '00008': 3,
#  '00008 according': 2,
#  '00008 according mi': 2,
#  '00008 approved': 1,
#  '00008 approved federal': 1,
#  '0001': 3,
#  '0001 population': 2,
#  '0001 population impose': 1,
#  '0001 population primarily': 1,
#  '00010': 1,
#  '00010 notice': 1,
#  '00010 notice violation': 1,
#  '00012': 1,
#  '00012 creepy': 1,
#  '00012 creepy joe': 1,
#  '00016': 1,
#  '00016 blm': 1,
#  '00016 blm antifa': 1,
#  '00017': 1,
#  '00017 thought': 1,
#  '00017 thought dilithium': 1,
#  '00018': 1,
#  '00018 solution': 1,
#  '00018 solution riot': 1,
#  '00019': 1,
#  '00019 america': 1,
#  '00019 america knew': 1,
#  '0002': 1,
#  '0002 50m': 1,
#  '0002 50m blog': 1,
#  '00022': 1,
#  '00022 class': 1,
#  '00022 class action': 1,
#  '00023': 2,
#  '00023 theirtube': 2,
#  '00023 theirtube 53': 2,
#  '00024': 1,
#  '00024 facebook': 1,
#  '00024 facebook platform': 1,
#  '00024153': 1,
#  '00026': 2,
#  '00026 stroppy': 2,
#  '00026 stroppy uncovers': 2,
#  '00029': 1,
#  '00029 glass': 1,
#  '00029 glass phone': 1,
#  '0003': 1,
#  '0003 death': 1,
#  '0003 death rate': 1,
#  '00031': 1,
#  '00031 911': 1,
#  '00031 911 christ': 1,
#  '00032': 1,
#  '00032 ghost': 1,
#  '00032 ghost ginsberg': 1,
#  '0003225': 1,
#  '0003225 governor': 1,
#  '0003225 governor sununu': 1,
#  '000385': 1,
#  '000385 survival': 1,
#  '000385 survival rate': 1,
#  '0004': 1,
#  '0004 cdc': 1,
#  '0004 cdc chart': 1,
#  '00041': 1,
#  '00041 surprise': 1,
#  '00041 surprise period': 1,
#  '000431': 1,
#  '000431 gmt': 1,
#  '000431 gmt read': 1,
#  '000451': 1,
#  '000451 gmt': 1,
#  '000451 gmt read': 1,
#  '0005': 3,
#  '0005 chance': 1,
#  '0005 chance someone': 1,
#  '0005 nj': 1,
#  '0005 nj 69': 1,
#  '0005 nothing': 1,
#  '0005 nothing see': 1,
#  '000500': 1,
#  '000500 gmt': 1,
#  '000500 gmt read': 1,
#  '000642': 1,
#  '000642 gmt': 1,
#  '000642 gmt read': 1,
#  '0007': 1,
#  '0007 ny': 1,
#  '0007 ny 300': 1,
#  '000725': 1,
#  '000725 gmt': 1,
#  '000725 gmt read': 1,
#  '00083': 1,
#  '00083 died': 1,
#  '00083 died globally': 1,
#  '000910': 1,
#  '000910 gmt': 1,
#  '000910 gmt read': 1,
#  '000928': 1,
#  '000928 gmt': 1,
#  '000928 gmt read': 1,
#  '000dwd': 1,
#  '000dwd want': 1,
#  '000dwd want know': 1,
#  '001': 26,
#  '001 1865660': 1,
#  '001 1865660 united': 1,
#  '001 34': 1,
#  '001 34 world': 1,
#  '001 death': 1,
#  '001 death decision': 1,
#  '001 judicialwatchs': 1,
#  '001 judicialwatchs broadcast': 1,
#  '001 justthenewss': 1,
#  '001 justthenewss broadcast': 1,
#  '001 mortality': 1,
#  '001 mortality rate': 1,
#  '001 role': 1,
#  '001 role vice': 1,
#  '001 rsbnetworks': 6,
#  '001 rsbnetworks broadcast': 6,
#  '001 seanhannitys': 1,
#  '001 seanhannitys broadcast': 1,
#  '001 teamtrumps': 2,
#  '001 teamtrumps broadcast': 2,
#  '001 vladivpgs': 9,
#  '001 vladivpgs broadcast': 9,
#  '001 waynedupreeshows': 1,
#  '001 waynedupreeshows broadcast': 1,
#  '001005': 2,
#  '001005 alertness': 2,
#  '001005 alertness judgment': 2,
#  '00111111': 1,
#  '00111111 jeannefentress': 1,
#  '00111111 jeannefentress traderjill77': 1,
#  '0012020': 1,
#  '0015': 1,
#  '0015 wuhanvirus': 1,
#  '0015 wuhanvirus covid19': 1,
#  '00154': 3,
#  '00154 judicial': 1,
#  '00154 judicial watch': 1,
#  '00154 pgs': 2,
#  '00154 pgs 6164': 2,
#  '0016': 1,
#  '0016 yet': 1,
#  '0016 yet stay': 1,
#  '001633': 1,
#  '001633 gmt': 1,
#  '001633 gmt read': 1,
#  '001c': 1,
#  '002': 19,
#  '002 breitbartnewss': 1,
#  '002 breitbartnewss broadcast': 1,
#  '002 case': 1,
#  '002 case big': 1,
#  '002 judicialwatchs': 1,
#  '002 judicialwatchs broadcast': 1,
#  '002 justthenewss': 1,
#  '002 justthenewss broadcast': 1,
#  '002 ld': 1,
#  '002 ld 00000623': 1,
#  '002 mortality': 1,
#  '002 mortality rate': 1,
#  '002 percent': 1,
#  '002 percent population': 1,
#  '002 role': 1,
#  '002 role vice': 1,
#  '002 seanhannitys': 1,
#  '002 seanhannitys broadcast': 1,
#  '002 share': 1,
#  '002 share hear': 1,
#  '002 teamtrumps': 1,
#  '002 teamtrumps broadcast': 1,
#  '002 vessel': 1,
#  '002 vessel advanced': 1,
#  '002 vladivpgs': 4,
#  '002 vladivpgs broadcast': 4,
#  '002 waynedupreeshows': 1,
#  '002 waynedupreeshows broadcast': 1,
#  '002 whitehouses': 2,
#  '002 whitehouses broadcast': 2,
#  '0020192': 1,
#  '0020192 alice': 1,
#  '0020192 alice wonderland': 1,
#  '0025': 1,
#  '0025 pound': 1,
#  '0025 pound sterling': 1,
#  '00269': 1,
#  '00269 green': 1,
#  '00269 green new': 1,
#  '00281697': 1,
#  '00281697 american': 1,
#  '00281697 american newspaper': 1,
#  '002875': 1,
#  '002875 pandemic': 1,
#  '002875 pandemic 9200': 1,
#  '002910': 1,
#  '002910 gmt': 1,
#  '002910 gmt read': 1,
#  '002948': 1,
#  '002948 gmt': 1,
#  '002948 gmt read': 1,
#  '003': 5,
#  '003 2020': 1,
#  '003 2020 2016': 1,
#  '003 2049': 1,
#  '003 2049 02': 1,
#  '003 257k': 1,
#  '003 257k view': 1,
#  '003 infected': 1,
#  '003 infected kid': 1,
#  '003 wtf': 1,
#  '0033': 1,
#  '003352': 1,
#  '003352 gmt': 1,
#  '003352 gmt read': 1,
#  '003478': 1,
#  '003478 bellingcat': 1,
#  '003701': 1,
#  '003701 gmt': 1,
#  '003701 gmt read': 1,
#  '003737': 1,
#  '003737 gmt': 1,
#  '003737 gmt read': 1,
#  '004': 4,
#  '004 african': 1,
#  '004 african blood': 1,
#  '004 atmosphere': 1,
#  '004 atmosphere propaganda': 1,
#  '004 le': 1,
#  '004 le common': 1,
#  '004 percent': 1,
#  '004 percent zero': 1,
#  '00441': 1,
#  '00441 judicial': 1,
#  '00441 judicial watch': 1,
#  '0045': 1,
#  '0045 rattled': 1,
#  '0045 rattled shaken': 1,
#  '004630': 1,
#  '004630 gmt': 1,
#  '004630 gmt read': 1,
#  '005': 2,
#  '005 come': 1,
#  '005 come like': 1,
#  '005 money': 1,
#  '005 money realdonaldtrump': 1,
#  '005028': 1,
#  '005028 gmt': 1,
#  '005028 gmt read': 1,
#  '0053': 1,
#  '0053 died': 1,
#  '0053 died usa': 1,
#  '005442': 1,
#  '005442 gmt': 1,
#  '005442 gmt read': 1,
#  '006': 2,
#  '006 micron': 1,
#  '006 micron 14': 1,
#  '006 unpaid': 1,
#  '006 unpaid tax': 1,
#  '006010': 2,
#  '006010 visual': 2,
#  '006010 visual tracking': 2,
#  '0060d': 1,
#  '0060d gene': 1,
#  '0060d gene la': 1,
#  '00666': 1,
#  '00666 10': 1,
#  '00666 10 telegraphed': 1,
#  '00687': 1,
#  '00687 clinton': 1,
#  '00687 clinton email': 1,
#  '007': 25,
#  '007 225': 1,
#  '007 225 law': 1,
#  '007 ancient': 1,
#  '007 ancient legacy': 1,
#  '007 black': 3,
#  '007 black woman': 3,
#  '007 casting': 1,
#  '007 daily': 1,
#  '007 daily mail': 1,
#  '007 get': 1,
#  '007 get woke': 1,
#  '007 got': 1,
#  '007 got woke': 1,
#  '007 ingredient': 1,
#  '007 ingredient cetylpyridinium': 1,
#  '007 invest': 1,
#  '007 invest saving': 1,
#  '007 james': 3,
#  '007 james bond': 3,
#  '007 know': 1,
#  '007 know like': 1,
#  '007 leaf': 1,
#  '007 leaf bond': 1,
#  '007 met': 1,
#  '007 met prince': 1,
#  '007 new': 1,
#  '007 new james': 1,
#  '007 read': 1,
#  '007 revealed': 1,
#  '007 revealed bond': 1,
#  '007 socalled': 1,
#  '007 socalled declaration': 1,
#  '007 standard': 1,
#  '007 standard absolve': 1,
#  '007 whitehouses': 1,
#  '007 whitehouses broadcast': 1,
#  '007g': 1,
#  '007g withstand': 1,
#  '007g withstand weight': 1,
#  '007q': 1,
#  '007q polo82fever': 1,
#  '007q polo82fever tweeted': 1,
#  '008': 8,
#  '008 040': 1,
#  '008 040 032': 1,
#  '008 avoicenewss': 1,
#  '008 avoicenewss broadcast': 1,
#  '008 bac': 2,
#  '008 bac impaired': 2,
#  '008 meter': 1,
#  '008 meter 315': 1,
#  '008 obliterate': 1,
#  '008 obliterate man': 1,
#  '008 realamvoices': 1,
#  '008 realamvoices broadcast': 1,
#  '008 retired': 1,
#  '008 retired navy': 1,
#  '00am': 1,
#  '00am meet': 1,
#  '00am meet secretary': 1,
#  '00o553l': 1,
#  '01': 64,
#  '01 0000': 1,
#  '01 0000 parrot': 1,
#  '01 01': 1,
#  '01 01 1900': 1,
#  '01 03': 1,
#  '01 05': 1,
#  '01 05 order': 1,
#  '01 1900': 1,
#  '01 1900 donald': 1,
#  '01 1961': 1,
#  '01 1961 august': 1,
#  '01 2019': 20,
#  '01 2019 ozy': 20,
#  '01 african': 1,
#  '01 african american': 1,
#  '01 america': 1,
#  '01 america democrat': 1,
#  '01 at': 1,
#  '01 at huckabee': 1,
#  '01 barrel': 2,
#  '01 barrel trump': 2,
#  '01 bayern': 1,
#  '01 bayern munich': 1,
#  '01 bg': 1,
#  '01 bg sub': 1,
#  '01 child': 2,
#  '01 child working': 2,
#  '01 cpc': 1,
#  '01 cpc leadership': 1,
#  '01 death': 3,
#  '01 death rate': 2,
#  '01 death related': 1,
#  '01 dec': 3,
#  '01 dec 2019': 3,
#  '01 donald': 1,
#  '01 donald trump': 1,
#  '01 flu': 1,
#  '01 flu since': 1,
#  '01 genesis': 1,
#  '01 genesis six': 1,
#  '01 go': 1,
#  '01 go camp': 1,
#  '01 inch': 1,
#  '01 inch past': 1,
#  '01 island': 1,
#  '01 island pond': 1,
#  '01 just': 1,
#  '01 just like': 1,
#  '01 like': 5,
#  '01 like seasonal': 5,
#  '01 maine': 1,
#  '01 maine 02': 1,
#  '01 micron': 1,
#  '01 micron mask': 1,
#  '01 moral': 1,
#  '01 moral side': 1,
#  '01 percent': 1,
#  '01 percent official': 1,
#  '01 pressure': 1,
#  '01 pressure massive': 1,
#  '01 price': 1,
#  '01 price tag': 1,
#  '01 sep': 1,
#  '01 sep 2020': 1,
#  '01 trying': 1,
#  '01 trying control': 1,
#  '010': 2,
#  '010 last': 1,
#  '010 last year': 1,
#  '010 uaathleticss': 1,
#  '010 uaathleticss broadcast': 1,
#  '0100': 2,
#  '0100 gmt': 1,
#  '0100 gmt june': 1,
#  '0100 much': 1,
#  '0100 much trust': 1,
#  '01000000000000': 2,
#  '01000000000000 01000000000000': 1,
#  '01000000000000 01000000000000 payable': 1,
#  '01000000000000 payable': 1,
#  '01000000000000 payable proven': 1,
#  '010104': 1,
#  '010104 edt': 1,
#  '010104 edt hs1jq13jv6': 1,
#  '01011800': 1,
#  '01011800 birthday': 1,
#  '01011800 birthday confidentiality': 1,
#  '010121': 1,
#  '010121 influenza': 1,
#  '010121 influenza renamed': 1,
#  '010208': 1,
#  '010208 pm': 1,
#  '010208 pm edt': 1,
#  '010220': 1,
#  '010220 gmt': 1,
#  '010220 gmt read': 1,
#  '01022016': 1,
#  '01022016 trump': 1,
#  '01022016 trump started': 1,
#  '010315': 1,
#  '010315 gmt': 1,
#  '010315 gmt read': 1,
#  '010332': 1,
#  '010332 pm': 1,
#  '010332 pm edt': 1,
#  '010539': 1,
#  '010539 pm': 1,
#  '010539 pm edt': 1,
#  '010621': 1,
#  '010621 congress': 1,
#  '010621 congress convene': 1,
#  '010759': 1,
#  '010759 gmt': 1,
#  '010759 gmt read': 1,
#  '010805': 1,
#  '010805 pm': 1,
#  '010805 pm edt': 1,
#  '010937': 1,
#  '010937 gmt': 1,
#  '010937 gmt read': 1,
#  '011': 1,
#  '011 3142928100': 1,
#  '011020': 2,
#  '011020 reasoning': 2,
#  '011020 reasoning depth': 2,
#  '011031': 1,
#  '011031 edt': 1,
#  '011031 edt hs1jq13jv6': 1,
#  '011057': 1,
#  '011057 pm': 1,
#  '011057 pm edt': 1,
#  '011105': 1,
#  '011105 gmt': 1,
#  '011105 gmt read': 1,
#  '011122': 1,
#  '011122 pm': 1,
#  '011122 pm edt': 1,
#  '011128': 1,
#  '011128 edt': 1,
#  '011128 edt anonymous': 1,
#  '011130': 1,
#  '011130 gmt': 1,
#  '011130 gmt read': 1,
#  '011232': 1,
#  '011232 edt': 1,
#  '011232 edt hs1jq13jv6': 1,
#  '011349': 1,
#  '011349 tweeted': 1,
#  '011349 tweeted susan': 1,
#  '011455': 1,
#  '011455 edt': 1,
#  '011455 edt hs1jq13jv6': 1,
#  '0115': 1,
#  '0115 pm': 1,
#  '0115 pm cna': 1,
#  '011629': 1,
#  '011629 gmt': 1,
#  '011629 gmt read': 1,
#  '011635': 1,
#  '011635 pm': 1,
#  '011635 pm edt': 1,
#  '011640': 1,
#  '011640 gmt': 1,
#  '011640 gmt read': 1,
#  '011659': 1,
#  '011659 pm': 1,
#  '011659 pm edt': 1,
#  '011824': 1,
#  '011824 pm': 1,
#  '011824 pm edt': 1,
#  '01202017': 1,
#  '01202017 inauguration': 1,
#  '01202017 inauguration president': 1,
#  '012021': 1,
#  '012055': 1,
#  '012055 pm': 1,
#  '012055 pm edt': 1,
#  '012058': 1,
#  '012058 est': 1,
#  '012058 est new': 1,
#  '012129': 1,
#  '012129 pm': 1,
#  '012129 pm edt': 1,
#  '012210': 1,
#  '012210 gmt': 1,
#  '012210 gmt read': 1,
#  '012242': 1,
#  '012242 gmt': 1,
#  '012242 gmt read': 1,
#  '01242': 3,
#  '01242 benghazi': 1,
#  '01242 benghazi rice': 1,
#  '01242 judicial': 2,
#  '01242 judicial watch': 2,
#  '012426': 1,
#  '012426 edt': 1,
#  '012426 edt hs1jq13jv6': 1,
#  '012500': 1,
#  '012500 gmt': 1,
#  '012500 gmt read': 1,
#  '012535': 1,
#  '012535 pm': 1,
#  '012535 pm edt': 1,
#  '012723': 1,
#  '012723 gmt': 1,
#  '012723 gmt read': 1,
#  '012736': 1,
#  '012736 est': 1,
#  '012736 est hs1jq13jv6': 1,
#  '012753': 1,
#  '012753 gmt': 1,
#  '012753 gmt read': 1,
#  '01282020': 1,
#  '01282020 150pm': 1,
#  '01282020 150pm est': 1,
#  '012849': 1,
#  '012849 pm': 1,
#  '012849 pm edt': 1,
#  '012857': 1,
#  '012857 pm': 1,
#  '012857 pm edt': 1,
#  '012937': 1,
#  '012937 pm': 1,
#  '012937 pm edt': 1,
#  '013': 5,
#  '013 mortality': 2,
#  '013 mortality rate': 2,
#  '013 second': 1,
#  '013 second marki': 1,
#  '013 thing': 1,
#  '013 thing backyard': 1,
#  '013 youn': 1,
#  '013 youn body': 1,
#  '0130': 1,
#  '0130 pm': 1,
#  '0130 pm edt': 1,
#  '013014': 1,
#  '013014 pm': 1,
#  '013014 pm edt': 1,
#  '013017': 1,
#  '013017 pm': 1,
#  '013017 pm edt': 1,
#  '013022': 1,
#  '013022 gmt': 1,
#  '013022 gmt read': 1,
#  '013058': 1,
#  '013058 pm': 1,
#  '013058 pm edt': 1,
#  '013106': 1,
#  '013106 pm': 1,
#  '013106 pm edt': 1,
#  '013120': 1,
#  '013120 boris': 1,
#  '013120 boris say': 1,
#  '013218': 1,
#  '013218 utc': 1,
#  '013252': 1,
#  '013252 pm': 1,
#  '013252 pm edt': 1,
#  '013318': 1,
#  '013318 gmt': 1,
#  '013318 gmt read': 1,
#  '013403': 1,
#  '013403 pm': 1,
#  '013403 pm edt': 1,
#  '013527': 1,
#  '013527 pm': 1,
#  '013527 pm edt': 1,
#  '013550': 1,
#  '013550 pm': 1,
#  '013550 pm edt': 1,
#  '013558': 1,
#  '013558 gmt': 1,
#  '013558 gmt read': 1,
#  '013559': 1,
#  '013559 pm': 1,
#  '013559 pm edt': 1,
#  '013633': 2,
#  '013633 pm': 2,
#  '013633 pm edt': 2,
#  '013731': 1,
#  '013731 pm': 1,
#  '013731 pm edt': 1,
#  '013809': 1,
#  '013809 edt': 1,
#  '013809 edt hs1jq13jv6': 1,
#  '013934': 1,
#  '013934 pm': 1,
#  '013934 pm edt': 1,
#  '014': 2,
#  '014 le': 1,
#  '014 le 1918': 1,
#  '014 waynedupreeshows': 1,
#  '014 waynedupreeshows broadcast': 1,
#  '014115': 1,
#  '014115 edt': 1,
#  '014115 edt hs1jq13jv6': 1,
#  '014126': 1,
#  '014126 gmt': 1,
#  '014126 gmt read': 1,
#  '014128': 1,
#  '014128 edt': 1,
#  '014128 edt hs1jq13jv6': 1,
#  '014134': 1,
#  '014134 pm': 1,
#  '014134 pm edt': 1,
#  '014349': 1,
#  '014349 gmt': 1,
#  '014349 gmt read': 1,
#  '014359': 1,
#  '014359 gmt': 1,
#  '014359 gmt read': 1,
#  '014608': 1,
#  '014608 edt': 1,
#  '014608 edt hs1jq13jv6': 1,
#  '014626': 1,
#  '014626 pm': 1,
#  '014626 pm edt': 1,
#  '014635': 1,
#  '014635 gmt': 1,
#  '014635 gmt read': 1,
#  '014833': 1,
#  '014833 pm': 1,
#  '014833 pm edt': 1,
#  '014903': 1,
#  '014903 gmt': 1,
#  '014903 gmt read': 1,
#  '014935': 1,
#  '014935 pm': 1,
#  '014935 pm edt': 1,
#  '015': 1,
#  '015036': 1,
#  '015036 gmt': 1,
#  '015036 gmt read': 1,
#  '015120': 1,
#  '015120 pm': 1,
#  '015120 pm edt': 1,
#  '015136': 1,
#  '015136 november': 1,
#  '015136 november 021432': 1,
#  '015400': 1,
#  '015400 gmt': 1,
#  '015400 gmt read': 1,
#  '015453': 1,
#  '015453 gmt': 1,
#  '015453 gmt read': 1,
#  '015544': 1,
#  '015544 gmt': 1,
#  '015544 gmt read': 1,
#  '015545': 1,
#  '015545 pm': 1,
#  '015545 pm edt': 1,
#  '015552': 1,
#  '015552 edt': 1,
#  '015552 edt hs1jq13jv6': 1,
#  '015658': 1,
#  '015658 gmt': 1,
#  '015658 gmt read': 1,
#  '015704': 1,
#  '015704 gmt': 1,
#  '015704 gmt read': 1,
#  '015718': 1,
#  '015718 pm': 1,
#  '015718 pm edt': 1,
#  '015746': 1,
#  '015746 pm': 1,
#  '015746 pm edt': 1,
#  '015818': 1,
#  '015818 pm': 1,
#  '015818 pm edt': 1,
#  '015902': 1,
#  '015902 gmt': 1,
#  '015902 gmt read': 1,
#  '015934': 1,
#  '015934 gmt': 1,
#  '015934 gmt read': 1,
#  '015935': 1,
#  '015935 gmt': 1,
#  '015935 gmt read': 1,
#  '016': 1,
#  '016 covid': 1,
#  '016 covid death': 1,
#  '017': 1,
#  '017 whitehouses': 1,
#  '017 whitehouses broadcast': 1,
#  '018': 8,
#  '018 089': 5,
#  '018 089 ny': 5,
#  '018 412anon87s': 1,
#  '018 412anon87s broadcast': 1,
#  '018 judicialwatchs': 1,
#  '018 judicialwatchs broadcast': 1,
#  '018 nfl': 1,
#  '018 nfl team': 1,
#  '019': 9,
#  '019 003': 1,
#  '019 003 2049': 1,
#  '019 99997': 3,
#  '019 99997 2049': 3,
#  '019 9999992': 1,
#  '019 9999992 2049': 1,
#  '019 biden': 1,
#  '019 biden staffer': 1,
#  '019 percent': 1,
#  '019 percent 11': 1,
#  '019 total': 1,
#  '019 total vote': 1,
#  '019 year': 1,
#  '019 year old': 1,
#  '0192pg': 1,
#  '0192pg criminal': 1,
#  '0192pg criminal justice': 1,
#  '01947': 1,
#  '01947 judicial': 1,
#  '01947 judicial watch': 1,
#  '01bac9': 4,
#  '01bac9 no10591873': 1,
#  '01bac9 no10591873 sep': 1,
#  '01bac9 no10592051': 1,
#  '01bac9 no10592051 sep': 1,
#  '01bac9 no10592228': 1,
#  '01bac9 no10592228 sep': 1,
#  '01bac9 no10592443': 1,
#  '01bac9 no10592443 sep': 1,
#  '01c': 1,
#  '01c global': 1,
#  '01c global temperature': 1,
#  '01h30min': 1,
#  '01jun19': 1,
#  '01jun19 thankyou': 1,
#  '01jun19 thankyou realdonaldtrump': 1,
#  '01quantum': 1,
#  '01ravenking': 1,
#  '01ravenking brownie55': 1,
#  '01ravenking brownie55 httpstco3lgvop6pes': 1,
#  '02': 74,
#  '02 08': 1,
#  '02 08 34': 1,
#  '02 18': 1,
#  '02 18 death': 1,
#  '02 20': 1,
#  '02 20 22865': 1,
#  '02 2002': 1,
#  '02 2002 beau': 1,
#  '02 2019': 34,
#  '02 2019 ozy': 34,
#  '02 2020': 2,
#  '02 2020 10': 1,
#  '02 34': 4,
#  '02 34 gateway': 4,
#  '02 5069': 1,
#  '02 5069 70': 1,
#  '02 60': 1,
#  '02 60 cortisol': 1,
#  '02 additionally': 1,
#  '02 additionally therapeutic': 1,
#  '02 bac': 4,
#  '02 bac christian': 2,
#  '02 bac one': 2,
#  '02 case': 2,
#  '02 case linked': 2,
#  '02 covid19': 1,
#  '02 covid19 death': 1,
#  '02 dec': 8,
#  '02 dec 2019': 8,
#  '02 feb': 1,
#  '02 feb 2020': 1,
#  '02 januaryjune': 1,
#  '02 januaryjune period': 1,
#  '02 man': 1,
#  '02 man many': 1,
#  '02 march': 1,
#  '02 march 2020': 1,
#  '02 not': 1,
#  '02 not 34': 1,
#  '02 pa': 1,
#  '02 pa rate': 1,
#  '02 putting': 1,
#  '02 putting price': 1,
#  '02 tested': 1,
#  '02 tested positive': 1,
#  '02 van': 1,
#  '02 van drew': 1,
#  '02 yet': 1,
#  '02 yet president': 1,
#  '0200720pm': 1,
#  '0200720pm edt': 1,
#  '0200720pm edt one': 1,
#  '020155': 1,
#  '020155 gmt': 1,
#  '020155 gmt read': 1,
#  '020159': 1,
#  '020159 gmt': 1,
#  '020159 gmt read': 1,
#  '02019cv60002': 1,
#  '02019cv60002 district': 1,
#  '02019cv60002 district court': 1,
#  '02022020': 2,
#  '02022020 cool': 1,
#  '02022020 cool palindrome': 1,
#  '020233': 1,
#  '020233 gmt': 1,
#  '020233 gmt read': 1,
#  '020440': 1,
#  '020440 gmt': 1,
#  '020440 gmt read': 1,
#  '02046': 1,
#  '02046 judicial': 1,
#  '02046 judicial watch': 1,
#  '020726': 1,
#  '020726 gmt': 1,
#  '020726 gmt read': 1,
#  '020734': 1,
#  '020734 gmt': 1,
#  '020734 gmt read': 1,
#  '02082020': 1,
#  '02082020 mediumcom': 1,
#  '020835': 1,
#  '020835 gmt': 1,
#  '020835 gmt read': 1,
#  '020839': 1,
#  '020839 gmt': 1,
#  '020839 gmt read': 1,
#  '020928': 1,
#  '020928 pm': 1,
#  '020928 pm edt': 1,
#  '021008': 1,
#  '021008 pm': 1,
#  '021008 pm edt': 1,
#  '021030': 2,
#  '021030 slurred': 2,
#  '021030 slurred speech': 2,
#  '021036': 1,
#  '021036 pm': 1,
#  '021036 pm edt': 1,
#  '021146': 1,
#  '021146 pm': 1,
#  '021146 pm edt': 1,
#  '021212': 1,
#  '021212 gmt': 1,
#  '021212 gmt read': 1,
#  '02122020': 1,
#  '02122020 752pm': 1,
#  '02122020 752pm est': 1,
#  '021313': 1,
#  '021313 pm': 1,
#  '021313 pm edt': 1,
#  '021325': 1,
#  '021325 pm': 1,
#  ...}

# %%
vectorizer = CountVectorizer(min_df=1, preprocessor=dummy_func, tokenizer=cust_tokenizer, ngram_range=(1,3))

# %%
test_tf = vectorizer.fit_transform(["#MAGA #TRUMP2020 Let's vote out these bloodsucking demoncrats!"])

# %%
test_counts = np.asarray(test_tf.sum(axis=0))[0]

# %%
test_names = vectorizer.get_feature_names()

# %%
test_freqs = dict(zip(test_names, term_counts))

# %%
for key in term_freqs:
    if "#" in key:
        print(key)

# %%
# %%time
# this is the top n freqs for comments

# vectorizing the posts
# initializing the vectorizer
# setting min doc freq to 1 release b/c of the small size of the corpus (not setting max df b/c of a fear of losing things)
vectorizer = CountVectorizer(min_df=1, ngram_range=(1,3))

# applying the vectorizer
tf = vectorizer.fit_transform(df[df["t"]=="c"]["bo"])

# pulling the terms
tf_feature_names = vectorizer.get_feature_names()

# pulling the term counts
term_counts = np.asarray(tf.sum(axis=0))[0]

# making a dictionary w/terms and term counts
term_freqs = dict(zip(tf_feature_names, term_counts))

# looks at the top 50 terms to be found here overall
# takes advantage of the return type of sorted (a list of tuples) and takes a slice before making a dict from that
dict((sorted(term_freqs.items(), key=lambda item: item[1],reverse=True))[0:50])
# Out:
# CPU times: total: 16 s
# Wall time: 16.1 s
# {'like': 9329,
#  'one': 9113,
#  'know': 8920,
#  'get': 8648,
#  'would': 8411,
#  'people': 8107,
#  'trump': 6590,
#  'good': 6589,
#  'exactly': 6382,
#  'right': 6244,
#  'time': 6105,
#  'think': 5487,
#  'need': 5409,
#  'amen': 5331,
#  'see': 5311,
#  'go': 5305,
#  'god': 4909,
#  'yes': 4903,
#  'going': 4709,
#  'want': 4660,
#  'got': 4396,
#  'thanks': 4203,
#  'never': 4105,
#  'lol': 3955,
#  'thank': 3936,
#  'year': 3876,
#  'make': 3815,
#  'cannot': 3755,
#  'say': 3710,
#  'great': 3670,
#  'state': 3650,
#  'back': 3523,
#  'agree': 3505,
#  'take': 3495,
#  'many': 3445,
#  'love': 3395,
#  'thing': 3277,
#  'way': 3246,
#  'well': 3206,
#  'look': 3131,
#  'president': 3129,
#  'democrat': 3100,
#  'day': 3092,
#  'could': 2910,
#  'even': 2861,
#  'vote': 2755,
#  'said': 2744,
#  'america': 2714,
#  'much': 2627,
#  'country': 2591}

# %%
# this finds hashtag term frequency
# sklearn removes the punctuation! -> that's the issue we're facing here :(
# https://stackoverflow.com/questions/39254134/how-to-preserve-punctuation-marks-in-scikit-learn-text-countvectorizer-or-tfidfv
# https://kavita-ganesan.com/how-to-use-countvectorizer/#.YiUnHOjMLD4

# %%
test = pd.read_json("ext_act_lang_filtered_pre_proc.ndjson", lines=True)

# %%
# regex pattern needed to find hashtags (#[a-zA-Z]+)

# %%
re.findall(r"(#[a-zA-Z]+)", "I hate these DEMONCRATS! #MAGA #TRUMP2020 We need to vote these suckers out!")
# Out:
# ['#MAGA', '#TRUMP']

# %%
test["hashtags"] = test["bo"].apply(hashtag_search)

# %%
test[test["hashtags"].notna()]
# Out:
#          t                                id        cd              c  \
# 0        p  3619348b91524430882f2b887838a3e4  20201018  1602989910000
# 1        p  1365051bfe6243599e6af1055b71c4a2  20201202  1606897009000
# 2        p  d755c2ce09e74c9b9b34953aae839554  20190829  1567070618000
# 3        p  a0124e3f9afa4fe29d404e41e3ac9a5f  20201009  1602262587000
# 4        p  857c1349a1cc4bfba84cb75a9a34ec93  20201026  1603746735000
# ...     ..                               ...       ...            ...
# 1266677  c  1f31dd86a29646598640c6ce5ca7d97c  20200830  1598759370000
# 1266678  c  3a1e2b23206f4955bfc25a24acaeff90  20200523  1590226917000
# 1266679  c  dc3fa8b7c12c4e3c898af4b14c99cbf5  20200727  1595810868000
# 1266680  c  1dc1abde35234e32a872bcf76bd6ab45  20200820  1597891420000
# 1266681  c  476d74eb1d2b4206b72cb02574c105a7  20200928  1601317643000
#
#                                         u               un  \
# 0        8b67993183a14587a001010058d089d2      chucknellis
# 1        eeeb8dd25b7142b1bc69cbdbe1d8bb62        ThomasFox
# 2        21031f424913456591d9a9aed4ff26c7      Cobrarick98
# 3        6e6d4f8e7479446f8f06d5d5c0fae9a3         AppleJax
# 4        eeeb8dd25b7142b1bc69cbdbe1d8bb62        ThomasFox
# ...                                   ...              ...
# 1266677  e11890c2ffc348df9cb703651a3cc9c0    LibertyElaine
# 1266678  8f30c4c4215249b583741639d4070a39       Clearskies
# 1266679  6e6d4f8e7479446f8f06d5d5c0fae9a3         AppleJax
# 1266680  efaac1ece6a893e0fab48f558e3a5c57  BethocAeilflaed
# 1266681  9ba302eb09584878ae72c873d550eb11   doutingthomas1
#
#                           dmn  \
# 0               noqreport.com
# 1                  rumble.com
# 2                 i.imgur.com
# 3        image-cdn.parler.com
# 4                deadline.com
# ...                       ...
# 1266677  image-cdn.parler.com
# 1266678  image-cdn.parler.com
# 1266679  image-cdn.parler.com
# 1266680  image-cdn.parler.com
# 1266681  image-cdn.parler.com
#
#                                                         bo  bo_lang  \
# 0        facebooks public policy manager global electio...  English
# 1        usps driver drop shocking claim 200000 ballot ...  English
# 2        antifa touch trump supporter coming take infec...  English
# 3        guilty charged election dirty democrat may pul...  English
# 4        60 minute trump walkoff soar 17m viewer watche...  English
# ...                                                    ...      ...
# 1266677  libertyelaine pelosi rigged midterm #midtermsr...  English
# 1266678                              going need bigger gun  English
# 1266679  yeah know bullshit also racist blame everythin...  English
# 1266680       full wine thing keeping sane teaching online  English
# 1266681                 going hook hoyer lift get basement  English
#
#                          conf  \
# 0        [0.8107684255000001]
# 1        [0.6809220314000001]
# 2        [0.8768866658000001]
# 3              [0.9819905758]
# 4              [0.7728871703]
# ...                       ...
# 1266677         [0.368270874]
# 1266678         [0.897129178]
# 1266679  [0.8486205935000001]
# 1266680        [0.6988052726]
# 1266681        [0.9862496853]
#
#                                                   hashtags
# 0                                                       []
# 1                                                       []
# 2                                                       []
# 3                                                       []
# 4                                                       []
# ...                                                    ...
# 1266677  [#midtermsrigged, #pelosicrimefamily, #pelosim...
# 1266678                                                 []
# 1266679                                                 []
# 1266680                                                 []
# 1266681                                                 []
#
# [1266682 rows x 11 columns]
